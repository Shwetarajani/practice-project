# %% [markdown]
# ### WEB SCRAPING-ASSIGNMENT3

# %%
from bs4 import BeautifulSoup
import requests
import selenium
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementClickInterceptedException
import pandas as pd
import time
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1.Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
# connect to webdriver
driver=webdriver.Chrome(r"C:\Users\youra\OneDrive\Desktop\SAI_dsp35\Datatrained\chromedriver.exe") 
time.sleep(2)

# to get url
url = "https://www.amazon.in/"
driver.get(url)

time.sleep(2)
# input the keywords that user wants to search
user_input = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : guitar

# %%
# to Locate searc_bar by id
search_bar = driver.find_element_by_id("twotabsearchtextbox") 
# to clear the search_bar
search_bar.clear() 
# to send user input to search bar
search_bar.send_keys(user_input)
 # to Locate search_button by xpath
search_button = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')      
search_button.click()

# %% [markdown]
# ### 2.In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
#collecting all the Product URLS
urls = []
for i in range(0,3):
    Page_urls=driver.find_elements_by_xpath("//a[@class='a-link-normal s-no-outline']")#collecting urls of all the laptop
    for i in Page_urls:
        urls.append(i.get_attribute('href'))
        
    #next button 
    nxt_btn=driver.find_element_by_xpath("//a[@class='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator']") 
    url=nxt_btn.get_attribute('href')
    driver.get(url)
    time.sleep(2)

# %%
#Making empty lists and scraping the required spots
Product_name = []
Brand_name= []
Ratings = []
No_Ratings = []
Price = []
Return = []
Expected_Delivery = []
Availability = []
Other_Details = []

#Start with for loop
for i in urls:
    driver.get(i)
    time.sleep(2)
    
    
    #Scraping product name
    try:
        prod=driver.find_element_by_xpath("//span[@id='productTitle']")
        Product_name.append(prod.text)
    except NoSuchElementException as e:
        Product_name.append("-")
        
        
    #Scraping brand name
    try:
        brand=driver.find_element_by_xpath("//div[@id='bylineInfo_feature_div']/div/a")
        Brand_name.append(brand.text)
    except NoSuchElementException as e:
        Brand_name.append("-")
        
        
     #Scraping Ratings
    try:
        rat=driver.find_element_by_xpath("//span[@id='acrPopover']")
        Ratings.append(rat.get_attribute("title"))   
    except NoSuchElementException as e:
        Ratings.append("-")
        
        
    #Scraping No of Ratings
    try:
        no_rat=driver.find_element_by_xpath("//a[@id='acrCustomerReviewLink']/span")
        No_Ratings.append(no_rat.text)
    except NoSuchElementException as e:
        No_Ratings.append("-")
        
        
    #Scraping Price
    try:
        pri=driver.find_element_by_xpath('//td[@class="a-span12"]')  
        Price.append(pri.text)
    except NoSuchElementException as e:
        Price.append("-")
        
        
    #Scraping Return/Exchange
    try:
        ret=driver.find_element_by_xpath("//div[@data-name='RETURNS_POLICY']/span/div[2]/a")
        Return.append(ret.text)
    except NoSuchElementException as e:
        Return.append("-")
        
     
    #Scraping  Expected_Delivery
    try:
        delivary=driver.find_element_by_xpath("//div[@id='ddmDeliveryMessage']/b")
        Expected_Delivery.append(delivary.text)
    except NoSuchElementException as e:
        Expected_Delivery.append("-")
        
        
    #Scraping Availability
    try:
        avai=driver.find_element_by_xpath("//div[@id='availability']/span")
        Availability.append(avai.text)
    except NoSuchElementException as e:
        Availability.append("-")
        
        
    #Scraping Other_Details
    try:
        details=driver.find_element_by_xpath("//ul[@class='a-unordered-list a-vertical a-spacing-mini']")
        Other_Details.append(details.text)
    except NoSuchElementException as e:
        Other_Details.append("-")
        
        
# To make dataframe
Guitar=pd.DataFrame({})
Guitar['Name'] = Product_name
Guitar['Brand'] = Brand_name
Guitar['Rating'] = Ratings
Guitar['No of Ratings'] = No_Ratings
Guitar['Price'] = Price
Guitar['Return'] = Return
Guitar['Expected_Delivery'] = Expected_Delivery
Guitar['Availability'] = Availability
Guitar['Other_Details'] = Other_Details
Guitar['Urls'] = urls

# %%
Guitar[]
# Out:
#                                                 Name  \
# 0  Kadence Frontier guitar with Online Guitar lea...
# 1  Kadence Frontier Jumbo Semi Acoustic Guitar Wi...
# 2  Vault Traveller 34 Inch Acoustic Guitar With B...
# 3  Blueberry 38C, 38" Acoustic Guitar Kit with Ba...
# 4  Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...
#
#                        Brand              Rating   No of Ratings      Price  \
# 0    Visit the Kadence Store  4.0 out of 5 stars   1,483 ratings  ₹5,399.00
# 1    Visit the Kadence Store  4.0 out of 5 stars   1,216 ratings  ₹7,348.00
# 2      Visit the VAULT Store  3.9 out of 5 stars     343 ratings          -
# 3  Visit the blueberry Store  3.8 out of 5 stars      14 ratings          -
# 4     Visit the JUAREZ Store  4.0 out of 5 stars  15,880 ratings          -
#
#                Return Expected_Delivery Availability  \
# 0  7 Days Replacement  Thursday, May 26
# 1  7 Days Replacement                 -    In stock.
# 2  7 Days Replacement                 -    In stock.
# 3  7 Days Replacement                 -    In stock.
# 4  7 Days Replacement                 -    In stock.
#
#                                        Other_Details  \
# 0  ★ Design - The High Gloss finish, Simple head ...
# 1  QUALITY STRINGS ---The surface is coated with ...
# 2  Size: 34" Steel stringed | Number of Strings: ...
# 3  Material: Top: linden wood, Side & Back: - lin...
# 4  Black Glossy Finish, Number of Frets: 18, Acou...
#
#                                                 Urls
# 0  https://www.amazon.in/gp/slredirect/picassoRed...
# 1  https://www.amazon.in/gp/slredirect/picassoRed...
# 2  https://www.amazon.in/gp/slredirect/picassoRed...
# 3  https://www.amazon.in/gp/slredirect/picassoRed...
# 4  https://www.amazon.in/Juarez-Acoustic-Cutaway-...

# %% [markdown]
# ### 3. Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes

# %%
import warnings
warnings.filterwarnings('ignore')


import selenium
import pandas as pd
from selenium import webdriver

# %%
driver = webdriver.Chrome(r"C:\Users\youra\OneDrive\Desktop\SAI_dsp35\Datatrained\chromedriver.exe")

driver.get('https://images.google.com/?gws_rd=ssl')

# %%
driver.get('https://images.google.com/?gws_rd=ssl')

l = driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
l.send_keys("fruits")
t=5
time.sleep(t)
p4 = driver.find_element_by_xpath("//span[@class='z1asCe MZy1Rb']")
p4.click()
time.sleep(t)

query="fruits"

for i in range(1, 11):

    try:
        img = driver.find_element_by_xpath('//*[@id="islrg"]/div[1]/div[' + str(i) + ']/a[1]/div[1]/img')
        img.screenshot('/Images/img' + query + ' (' + str(i) + ').png')
        time.sleep(0.2)
    except:
        continue

# %%
driver.get('https://images.google.com/?gws_rd=ssl')

l = driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
l.send_keys("cars")
t=5
time.sleep(t)
p4 = driver.find_element_by_xpath("//span[@class='z1asCe MZy1Rb']")
p4.click()
time.sleep(t)

query="cars"

for i in range(1, 11):

    try:
        img = driver.find_element_by_xpath('//*[@id="islrg"]/div[1]/div[' + str(i) + ']/a[1]/div[1]/img')
        img.screenshot('C:/Users/Jay gawande/Desktop/Images/img' + query + ' (' + str(i) + ').png')
        time.sleep(0.2)
    except:
        continue

# %%
driver.get('https://images.google.com/?gws_rd=ssl')

l = driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
l.send_keys("machine learning")
t=5
time.sleep(t)
p4 = driver.find_element_by_xpath("//span[@class='z1asCe MZy1Rb']")
p4.click()
time.sleep(t)

query="machine learning"

for i in range(1, 11):

    try:
        img = driver.find_element_by_xpath('//*[@id="islrg"]/div[1]/div[' + str(i) + ']/a[1]/div[1]/img')
        img.screenshot('C:/Users/Jay gawande/Desktop/Images/img' + query + ' (' + str(i) + ').png')
        time.sleep(0.2)
    except:
        continue

# %%
driver.get('https://images.google.com/?gws_rd=ssl')

l = driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
l.send_keys("guitar")
t=5
time.sleep(t)
p4 = driver.find_element_by_xpath("//span[@class='z1asCe MZy1Rb']")
p4.click()
time.sleep(t)

query="guitar"

for i in range(1, 11):

    try:
        img = driver.find_element_by_xpath('//*[@id="islrg"]/div[1]/div[' + str(i) + ']/a[1]/div[1]/img')
        img.screenshot('C:/Users/Jay gawande/Desktop/Images/img' + query + ' (' + str(i) + ').png')
        time.sleep(0.2)
    except:
        continue

# %%
driver.get('https://images.google.com/?gws_rd=ssl')

l = driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
l.send_keys("cake")
t=5
time.sleep(t)
p4 = driver.find_element_by_xpath("//span[@class='z1asCe MZy1Rb']")
p4.click()
time.sleep(t)

query="cake"

for i in range(1, 11):

    try:
        img = driver.find_element_by_xpath('//*[@id="islrg"]/div[1]/div[' + str(i) + ']/a[1]/div[1]/img')
        img.screenshot('C:/Users/Jay gawande/Desktop/Images/img' + query + ' (' + str(i) + ').png')
        time.sleep(0.2)
    except:
        continue

# %% [markdown]
# ### 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV

# %%
import warnings
warnings.filterwarnings('ignore')


import selenium
import pandas as pd
from selenium import webdriver

driver = webdriver.Chrome(r"C:\Users\youra\OneDrive\Desktop\SAI_dsp35\Datatrained\chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/')
t=3
time.sleep(t)

l = driver.find_element_by_xpath("//input[@class='_3704LK']")
l.send_keys("pixel")

# %%
p = driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
p.click()

# %%
name = driver.find_elements_by_xpath("//div[@class='_4rR01T']")
n3=[]
for i in name:
    title = i.text.split('\n')
    n3.append(title)
    
n3

price = driver.find_elements_by_xpath("//div[@class='_30jeq3 _1_WHN1']")
p=[]
for i in price:
    title = i.text
    p.append(title)
    
p

r = driver.find_elements_by_xpath("//ul[@class='_1xgFaf']")
r1=[]
for i in r:
    title = i.text.split('\n')[0]
    r1.append(title)
    
d=[]
for i in r:
    title = i.text.split('\n')[1]
    d.append(title)

c=[]
for i in r:
    title = i.text.split('\n')[2]
    c.append(title)
    
b=[]
for i in r:
    title = i.text.split('\n')[3]
    b.append(title)



url=[]
for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):
    url.append(i.get_attribute("href"))

# %%
ph=pd.DataFrame({})
ph['brand and phone name']=n3
ph['product url']=url
ph['ram/rom']=r1
ph['cameras']=c
ph['display size']=d
ph['battery capacity']=b
ph['price']=p
ph
# Out:
#                                 brand and phone name  \
# 0             [Google Pixel 4a (Just Black, 128 GB)]
# 1           [Google Pixel 3a (Clearly White, 64 GB)]
# 2                   [vivo T1 44W (Ice Dawn, 128 GB)]
# 3                                     [Cellecor C4i]
# 4                 [vivo T1 44W (Starry Sky, 128 GB)]
# 5                 [vivo T1 44W (Starry Sky, 128 GB)]
# 6                   [vivo T1 44W (Ice Dawn, 128 GB)]
# 7                 [vivo T1 44W (Starry Sky, 128 GB)]
# 8            [vivo T1 44W (Midnight Galaxy, 128 GB)]
# 9            [vivo T1 44W (Midnight Galaxy, 128 GB)]
# 10           [vivo T1 44W (Midnight Galaxy, 128 GB)]
# 11          [Infinix Smart 6 (Starry Purple, 64 GB)]
# 12            [Infinix Smart 6 (Polar Black, 64 GB)]
# 13  [OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)]
# 14           [Redmi 9A Sport (Metallic Blue, 32 GB)]
# 15             [vivo T1 Pro 5G (Turbo Cyan, 128 GB)]
# 16            [vivo T1 Pro 5G (Turbo Black, 128 GB)]
# 17                   [REDMI 10A (Slate grey, 64 GB)]
# 18                     [REDMI 10A (Sea Blue, 64 GB)]
# 19                [vivo Y21G (Midnight Blue, 64 GB)]
# 20          [MOTOROLA edge 30 (Meteor Grey, 128 GB)]
# 21           [REDMI 10 Prime (Astral White, 128 GB)]
# 22  [OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)]
# 23             [Redmi 9A Sport (Coral Green, 32 GB)]
#
#                                           product url  \
# 0   https://www.flipkart.com/google-pixel-4a-just-...
# 1   https://www.flipkart.com/google-pixel-3a-clear...
# 2   https://www.flipkart.com/vivo-t1-44w-ice-dawn-...
# 3   https://www.flipkart.com/cellecor-c4i/p/itmd3a...
# 4   https://www.flipkart.com/vivo-t1-44w-starry-sk...
# 5   https://www.flipkart.com/vivo-t1-44w-starry-sk...
# 6   https://www.flipkart.com/vivo-t1-44w-ice-dawn-...
# 7   https://www.flipkart.com/vivo-t1-44w-starry-sk...
# 8   https://www.flipkart.com/vivo-t1-44w-midnight-...
# 9   https://www.flipkart.com/vivo-t1-44w-midnight-...
# 10  https://www.flipkart.com/vivo-t1-44w-midnight-...
# 11  https://www.flipkart.com/infinix-smart-6-starr...
# 12  https://www.flipkart.com/infinix-smart-6-polar...
# 13  https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 14  https://www.flipkart.com/redmi-9a-sport-metall...
# 15  https://www.flipkart.com/vivo-t1-pro-5g-turbo-...
# 16  https://www.flipkart.com/vivo-t1-pro-5g-turbo-...
# 17  https://www.flipkart.com/redmi-10a-slate-grey-...
# 18  https://www.flipkart.com/redmi-10a-sea-blue-64...
# 19  https://www.flipkart.com/vivo-y21g-midnight-bl...
# 20  https://www.flipkart.com/motorola-edge-30-mete...
# 21  https://www.flipkart.com/redmi-10-prime-astral...
# 22  https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 23  https://www.flipkart.com/redmi-9a-sport-coral-...
#
#                                            ram/rom  \
# 0                            6 GB RAM | 128 GB ROM
# 1                             4 GB RAM | 64 GB ROM
# 2     8 GB RAM | 128 GB ROM | Expandable Upto 1 TB
# 3    32 MB RAM | 32 MB ROM | Expandable Upto 32 GB
# 4     4 GB RAM | 128 GB ROM | Expandable Upto 1 TB
# 5     8 GB RAM | 128 GB ROM | Expandable Upto 1 TB
# 6     4 GB RAM | 128 GB ROM | Expandable Upto 1 TB
# 7     6 GB RAM | 128 GB ROM | Expandable Upto 1 TB
# 8     8 GB RAM | 128 GB ROM | Expandable Upto 1 TB
# 9     6 GB RAM | 128 GB ROM | Expandable Upto 1 TB
# 10    4 GB RAM | 128 GB ROM | Expandable Upto 1 TB
# 11   2 GB RAM | 64 GB ROM | Expandable Upto 512 GB
# 12   2 GB RAM | 64 GB ROM | Expandable Upto 512 GB
# 13                           6 GB RAM | 128 GB ROM
# 14   3 GB RAM | 32 GB ROM | Expandable Upto 512 GB
# 15                           8 GB RAM | 128 GB ROM
# 16                           8 GB RAM | 128 GB ROM
# 17                            4 GB RAM | 64 GB ROM
# 18                            4 GB RAM | 64 GB ROM
# 19     4 GB RAM | 64 GB ROM | Expandable Upto 1 TB
# 20                           6 GB RAM | 128 GB ROM
# 21  6 GB RAM | 128 GB ROM | Expandable Upto 512 GB
# 22                           8 GB RAM | 128 GB ROM
# 23   2 GB RAM | 32 GB ROM | Expandable Upto 512 GB
#
#                                       cameras  \
# 0       12.2MP Rear Camera | 8MP Front Camera
# 1       12.2MP Rear Camera | 8MP Front Camera
# 2        50MP + 2MP + 2MP | 16MP Front Camera
# 3                           0.8MP Rear Camera
# 4        50MP + 2MP + 2MP | 16MP Front Camera
# 5        50MP + 2MP + 2MP | 16MP Front Camera
# 6        50MP + 2MP + 2MP | 16MP Front Camera
# 7        50MP + 2MP + 2MP | 16MP Front Camera
# 8        50MP + 2MP + 2MP | 16MP Front Camera
# 9        50MP + 2MP + 2MP | 16MP Front Camera
# 10       50MP + 2MP + 2MP | 16MP Front Camera
# 11       8 MP + Depth Lens | 5MP Front Camera
# 12       8 MP + Depth Lens | 5MP Front Camera
# 13                           64MP Rear Camera
# 14        13MP Rear Camera | 5MP Front Camera
# 15       64MP + 8MP + 2MP | 16MP Front Camera
# 16       64MP + 8MP + 2MP | 16MP Front Camera
# 17                           13MP Rear Camera
# 18                           13MP Rear Camera
# 19              13MP + 2MP | 8MP Front Camera
# 20      50MP + 50MP + 2MP | 32MP Front Camera
# 21  50MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 22                           64MP Rear Camera
# 23        13MP Rear Camera | 5MP Front Camera
#
#                                     display size  \
# 0          14.76 cm (5.81 inch) Full HD+ Display
# 1           14.22 cm (5.6 inch) Full HD+ Display
# 2   16.36 cm (6.44 inch) Full HD+ AMOLED Display
# 3                     4.57 cm (1.8 inch) Display
# 4   16.36 cm (6.44 inch) Full HD+ AMOLED Display
# 5   16.36 cm (6.44 inch) Full HD+ AMOLED Display
# 6   16.36 cm (6.44 inch) Full HD+ AMOLED Display
# 7   16.36 cm (6.44 inch) Full HD+ AMOLED Display
# 8   16.36 cm (6.44 inch) Full HD+ AMOLED Display
# 9   16.36 cm (6.44 inch) Full HD+ AMOLED Display
# 10  16.36 cm (6.44 inch) Full HD+ AMOLED Display
# 11               16.76 cm (6.6 inch) HD+ Display
# 12               16.76 cm (6.6 inch) HD+ Display
# 13                  16.74 cm (6.59 inch) Display
# 14              16.59 cm (6.53 inch) HD+ Display
# 15  16.36 cm (6.44 inch) Full HD+ AMOLED Display
# 16  16.36 cm (6.44 inch) Full HD+ AMOLED Display
# 17                  16.59 cm (6.53 inch) Display
# 18                  16.59 cm (6.53 inch) Display
# 19              16.54 cm (6.51 inch) HD+ Display
# 20         16.64 cm (6.55 inch) Full HD+ Display
# 21           16.51 cm (6.5 inch) Full HD Display
# 22                  16.74 cm (6.59 inch) Display
# 23              16.59 cm (6.53 inch) HD+ Display
#
#                    battery capacity    price
# 0                  3140 mAh Battery  ₹31,999
# 1                  3000 mAh Battery  ₹39,999
# 2          5000 mAh Lithium Battery  ₹17,999
# 3                  1000 mAh Battery   ₹1,098
# 4          5000 mAh Lithium Battery  ₹14,499
# 5          5000 mAh Lithium Battery  ₹17,999
# 6          5000 mAh Lithium Battery  ₹14,499
# 7          5000 mAh Lithium Battery  ₹15,999
# 8          5000 mAh Lithium Battery  ₹17,999
# 9          5000 mAh Lithium Battery  ₹15,999
# 10         5000 mAh Lithium Battery  ₹14,499
# 11  5000 mAh Li-ion Polymer Battery   ₹7,499
# 12  5000 mAh Li-ion Polymer Battery   ₹7,499
# 13                 5000 mAh Battery  ₹19,879
# 14                 5000 mAh Battery   ₹8,097
# 15         4700 mAh Lithium Battery  ₹24,999
# 16         4700 mAh Lithium Battery  ₹24,999
# 17                 5000 mAh Battery   ₹9,459
# 18                 5000 mAh Battery   ₹9,952
# 19         5000 mAh Lithium Battery  ₹13,499
# 20         4020 mAh Lithium Battery  ₹27,999
# 21                 6000 mAh Battery  ₹14,231
# 22                 5000 mAh Battery  ₹21,999
# 23                 5000 mAh Battery   ₹6,987

# %% [markdown]
# ### 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
import pandas as pd
import selenium
from selenium import webdriver
import re
import requests
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
# opening google maps
driver=webdriver.Chrome(r"C:\Users\youra\OneDrive\Desktop\SAI_dsp35\Datatrained\chromedriver.exe")
driver.get("https://www.google.co.in/maps")
time.sleep(3)

# %%
city = input('Enter City Name : ')                                       
search = driver.find_element_by_id("searchboxinput")                    
search.clear()                                                             
time.sleep(2)
search.send_keys(city)                                                    
button = driver.find_element_by_id("searchbox-searchbutton")              
button.click()                                                          
time.sleep(3)

try:
    url_string = driver.current_url
    print("URL Extracted: ", url_string)
    lat_lng = re.findall(r'@(.*)data',url_string)
    if len(lat_lng):
        lat_lng_list = lat_lng[0].split(",")
        if len(lat_lng_list)>=2:
            lat = lat_lng_list[0]
            lng = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(lat, lng))

except Exception as e:
        print("Error: ", str(e))
# Out:
# Enter City Name : Indore
# URL Extracted:  https://www.google.co.in/maps/@12.9972612,77.7108574,14z

# %% [markdown]
# ### 6.Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21) from trak.in.

# %%
#importing all the required libraries
import pandas as pd
import selenium
from selenium import webdriver
import re
import requests
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
driver=webdriver.Chrome(r"C:\Users\youra\OneDrive\Desktop\SAI_dsp35\Datatrained\chromedriver.exe")
driver.get("https://trak.in")
time.sleep(3)

# %%
#Selecting Search Button.
search_button = driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href')
driver.get(search_button)

# %%
#creating Empty List:
trade_dict = {}
trade_dict['Date'] = []
trade_dict['Startup Name'] = []
trade_dict['Industry/Vertical'] = []
trade_dict['Sub-Vertical'] = []
trade_dict['Location'] = []
trade_dict['Investor'] = []
trade_dict['Investment Type'] = []
trade_dict['Amount(in USD)'] = []
for i in range(40,51):
    driver.find_element_by_xpath('//div[@id="tablepress-{}_wrapper"]/div/label/select/option[4]'.format(i)).click()

    # Date
    dt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
    for d in dt:
        trade_dict['Date'].append(d.text)

    # Startup Name
    sn = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
    for n in sn:
        trade_dict['Startup Name'].append(n.text)
    
    # Industry/Vertical
    ind = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
    for n in ind:
        trade_dict['Industry/Vertical'].append(n.text)
    
    # Sub-Vertical
    sv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
    for s in sv:
        trade_dict['Sub-Vertical'].append(s.text)

    # Location
    loc = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
    for l in loc:
        trade_dict['Location'].append(l.text)
    
    # Investor
    inv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
    for n in inv:
        trade_dict['Investor'].append(n.text)
    
    # Investment Type
    invt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
    for n in invt:
        trade_dict['Investment Type'].append(n.text)
    
    # Amount
    amt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
    for a in amt:
        trade_dict['Amount(in USD)'].append(a.text)
    
trade_df = pd.DataFrame(trade_dict)
trade_df.head()
# Out:
#          Date                  Startup Name    Industry/Vertical  \
# 0  13/11/2019                    Freshworks             Software
# 1  14/11/2019                       Misters  Health and wellness
# 2  13/11/2019  Sunstone Eduversity Pvt. Ltd            Education
# 3  17/11/2019                  Burger Singh    Food and Beverage
# 4  18/11/2019                    Healthians  Health and Wellness
#
#                              Sub-Vertical       Location  \
# 0  Business and customer engagement tools  San Francisco
# 1         Men's Health and Wellness brand        Gurgaon
# 2                               Elearning        Gurgaon
# 3                     Indian Burger Brand        Gurgaon
# 4                     Healthcare services        Gurgaon
#
#                                             Investor Investment Type  \
# 0                           Sequoia, CapitalG, Accel        Series H
# 1                      Sauce.vc, Rainforest Ventures        Series B
# 2  Prime Venture Partners, LetsVenture, PS1 Ventu...            Seed
# 3                                     RB Investments         Venture
# 4                   DG Daiwa Ventures, DG Incubation        Series B
#
#   Amount(in USD)
# 0    15,000,0000
# 1        486,000
# 2      1,500,000
# 3    undisclosed
# 4     12,000,000

# %% [markdown]
# ### 7. Write a program to scrap all the available details of best gaming laptops from digit.in

# %%
#importing all the required libraries
import pandas as pd
import selenium
from selenium import webdriver
import re
import requests
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from bs4 import BeautifulSoup

# %%
driver=webdriver.Chrome(r"C:\Users\youra\OneDrive\Desktop\SAI_dsp35\Datatrained\chromedriver.exe")
time.sleep(6)

url = "https://www.digit.in"
driver.get(url)
driver.maximize_window()

# %%
url = 'https://www.digit.in/top-products/best-gaming-laptops-40.html'
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
htmlContent= page.content
soup= BeautifulSoup(htmlContent,'html.parser')

# %%
laptopdetails=[]
for i in soup.find_all("div", class_='value'):
    laptopdetails.append(i.text)
    
laptopname=[]
for i in soup.find_all("div", class_='Top10-Seller'):
    laptopname.append(i.text.replace('\n',','))

# %%
laptopname
# Out:
# [', List Of Best Gaming Laptops In India  (May 2022),,,,Product Name,Seller,Price,,,,,MSI Raider GE76,,Amazon,,,₹ 429,940,,,,ASUS ROG Strix Scar 15,,Amazon,,,₹ 285,390,,,,Acer Nitro 5,,Flipkart,,,₹ 129,990,,,,MSI Stealth 15M,,Flipkart,,,₹ 134,990,,,,ASUS ROG Strix Scar 15,,Croma,,,₹ 193,990,,,,ASUS ROG Strix Scar 15,,Flipkart,,,₹ 215,990,,,,ASUS ZEPHYRUS G14,,Croma,,,₹ 144,990,,,,HP Omen 16,,Amazon,,,₹ 139,990,,,,ASUS ROG ZEPHYRUS DUO 15,,Amazon,,,₹ 185,000,,,,Acer Aspire 7 gaming laptop,,Croma,,,₹ 53,490,,,,,']

# %%
laptopdetails
# Out:
# ['Windows 11 Home',
#  '17" (3840 x 2160)',
#  '12th Gen Intel Core i9-12900HK | 5 GHz',
#  '2 TB SSD/16 GBGB DDR5',
#  'Windows 11 Home',
#  '15.6" (2560 x 1440)',
#  '12th Gen Intel Core i9-12900H | 2.5 GHz',
#  '2 TB SSD/32 GBGB DDR5',
#  'Windows 10',
#  '15.6" (1920 x 1080)',
#  'AMD Ryzen 9 Octa Core | 2.4 GHz',
#  '1 TB HDD/16 GBGB DDR4',
#  'Windows 10',
#  '15.6" (1920 x 1080)',
#  'Intel Core i7 11th Gen - 11375H  | NA',
#  '1 TB SSD/16 GBGB DDR4',
#  'Windows 10',
#  '15.6" (2560 x 1440)',
#  'AMD Ryzen 9 Octa Core - 5900HX | 3.3 GHz',
#  '2 TB SSD/32 GBGB DDR4',
#  'Windows 10 Home',
#  '15.6" (1920 x 1080)',
#  'AMD Ryzen™ 9 5900HX | 3.3 GHz',
#  '1 TB SSD/16 GBGB DDR4',
#  'Windows 10 Home',
#  '14" (1920 x 1080)',
#  'AMD 3rd Gen Ryzen 9 | 3.3 GHz',
#  '1 TB SSD/16 GBGB DDR4',
#  'Windows 11 Home',
#  '16.1" (1920 x 1080)',
#  '12th Gen Intel Core i7-12700H | 4.7 GHz',
#  '1 TB SSD/16 GBGB \u200eDDR4',
#  'Windows 10',
#  '15.6" (3840 x 1100)',
#  'Intel Core i7 10th Gen 10875H  | NA',
#  '512 GB SSD/4 GBGB DDR4',
#  'Windows 10 Home',
#  '15.6" (1920 x 1080)',
#  'AMD Ryzen™ 5-5500U hexa-core  | NA',
#  '512 GB SSD/8 GBGB DDR4']

# %% [markdown]
# ### 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
url = "https://www.forbes.com/worlds-billionaires/?sh=485632655864"
page2 = requests.get(url)
soup2 = BeautifulSoup(page2.content)

# %%
bill_name = []
for i in soup2.find_all("div", class_='personName'):
    bill_name.append(i.text)

# %%
rank_name = []
for i in soup2.find_all("div", class_='rank'):
    rank_name.append(i.text)

# %% [markdown]
# ### 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
# to get web browser
driver=webdriver.Chrome(r"C:\Users\youra\OneDrive\Desktop\SAI_dsp35\Datatrained\chromedriver.exe") 
time.sleep(2)
# to get url
url = "https://www.youtube.com/"
driver.get(url)
time.sleep(2)

# %%
# input the keywords that user wants to search
user_input = input('Enter the video you want to search : ')

#finding element for search bar
search_bar = driver.find_element_by_xpath('//input[@id="search"]')
search_bar.send_keys(user_input)
time.sleep(1)
# Out:
# Enter the video you want to search : RRR

# %%
#clicking on search button
search_btn = driver.find_element_by_id("search-icon-legacy")  
search_btn.click()
time.sleep(1)

# %%
#clicking on first video
link_click = driver.find_element_by_xpath("//yt-formatted-string[@class ='style-scope ytd-video-renderer']")
link_click.click()

# 10000 time we scroll down to generate more Comments
for _ in range(10000):
    driver.execute_script("window.scrollBy(0,500)")

# %%
# empty lists
comments = []
comment_time = []
Time = []
Likes = []
No_of_Likes = []

# to scrape comments
cm_tags = driver.find_elements_by_id("content-text")
for cm in cm_tags:
    if cm.text is None:
        comments.append("--")
    else:
        comments.append(cm.text)
time.sleep(5)
comments[:500]
# Out:
# ['ఈ సినిమా ప్రపంచ వ్యాప్తంగా భారీ విజయం\nసాధించినందుకు చాలా ఆనందంగా ఉంది 🤩❤\nఎన్టీఆర్ అన్న యాక్టింగ్ అంటే ఎంతమందికి ఇష్టం',
#  'థియేటర్ లో ఈ సీన్ చూస్తున్నంత సేపు కన్నీళ్లు ఆగలేదు. Hats of to NTR  Sir ♥️. నీలాంటి గొప్ప నటుడిని  పొందినందుకు తెలుగు ఇండస్ట్రీ కి చాలా గర్వంగా ఉంది. 🔥',
#  'నటనలో అద్భుతాలు సృష్టించగల ఒకేఒక నటుడు జూ.ఎన్టీఆర్........జై ఎన్.టి.ఆర్......\nఆస్కార్ అవార్డు పర్ఫామెన్స్ అన్నా నీ నటనకు తెలుగు సినిమా బాన్సెన్ అంటోంది',
#  'అన్న ఎన్టీఆర్ నటనకు ఆస్కార్ అవార్డు ఇవ్వాలి అని ఎందరు అనుకుంటున్నారు\nJai Ntr❤💪',
#  'రామ్ చరణ్ గారి నటన అద్భుతం. ఒక వైపు బాధ,మరో వైపు బాధ్యత మరియు తాను సాధించాల్సిన లక్ష్యం.ntr ,చరణ్ గార్ల నటన అద్భుతం. 💐💐💐',
#  'i couldn’t understand a word (am north INDIAN) but tears were rolling down my eyes! my blood boiling in anger! 😭🇮🇳💎 i love RRR! 😭♥️',
#  'ఈ పాట థియేటర్ లో చూసి ఎంత మంది NTR అన్నా నటణకి ఫిదా అయ్యారు 💥🔥💥',
#  'నటవిశ్వరూపం మనువడు అని అనిపించారు మన Jr.NTR... తెలుగు సాహిత్యం లోని  గొప్పదనాన్ని తెలిపే పాట... ఆ పాట కి ఎంతో కృషి చేసిన కళాకారులకి అభివందనం తెలియచెప్పుకోవాలి..',
#  'యాక్షన్ అయిన ఎమోషనల్ అయిన devotional అయిన సెంటిమెంట్ అయిన అన్నీ కేటగిరీ లో అద్భుతమయిన విశ్వరూపాన్ని చూపించేది ఒక్క ntr hero ne ❤️❤️🙏',
#  'This video is very good, light and compact, very comfortable to listen to, and it has the feeling of dancing! ! ! Great',
#  'పాటకు తన నటనతో ప్రాణం పోసాడు\nProud to be NTR fan 🔥🔥🔥🔥',
#  'చాలా రోజులనుండి ఎదురుచూస్తున్న పాట "కొమురం భీముడో" పాటలో Ntr అన్న నటన అద్భుతం👌💐💐అశోక్ తేజ గారికి, కాలభైరవ గారికి ధన్యవాదములు',
#  'ఈ పాట చరిత్ర చిరస్థాయిగా మిగిలిపోతుంది the best emotional song… hats off to Jr NTR and Ram Charan and all who involved in this epic👏👏',
#  'ఎలాంటి వారికైన కంట నీరు పెటించే పాట, అభినందనలు కీరవాణి గారు..💐🇮🇳',
#  'దేశం గర్వించదగ్గ నటుడు తెలుగు వాడు అయినందుకు గర్వముగా ఉంది... నట విశ్వరూపం చూపించిన NTR😍🥰',
#  "Language doesn't matter, Kolleywood's music has won the hearts of the whole world. Love from Nepal.",
#  'సంపూర్ణ నటుడు అనే పదానికి నిర్వచనం 🙏\nNTR - నటన లో తిరుగులేని రారాజు 🔥🙇     \n                - NTR ARMY 🔥🔥🔥🔥🔥\n❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️',
#  'NTR లాంటి నటుడు మన తెలుగు సినీ పరిశ్రమలో పుట్టడం మన అద్రుష్టం \nఆయన అభిమాని గ చాలా గర్వపడుతున్నా \nజై NTR జైనందముారి',
#  'కళ్లతో కూడా నటించే నటుడు తెలుగు వాడై ఉన్నడుకు నాకు చాలా గర్వంగా ఉంది . సంపూర్ణ నటుడు అనే పదానికి నిర్వచనం 🙏 . భారతదేశం గర్వించదగ్గ నటుడు ఎన్టీఆర్ అన్న..',
#  'NTR నటన అద్భుతం .....\nNTR Fans Club 🤗',
#  'జీవితాంతం గుర్తుండిపోయే పాట 🔥❤️ఈ పాట కి Jr.Ntr అన్న చేసిన న్యాయం ఇంకా ఎవరు చేయలేరు. సింగిల్ పాట తో సినిమా డబ్బులు వసూలు అయిపోయింది జై Ntr జై జై Ntr🙏',
#  'నటన కి కూడా ఆశ్చర్యం అనిపించింది.... ఇంత అద్భుతంగా ఉంటాదా అని...ntr అన్న ..నీ అభిమాని అని గర్వపడుతున్నాను....జై NTR',
#  'భారత దేశంలో అత్యుత్తమ నటుడు....మా అన్న తారక్ ♥️ జై ఎన్టీఆర్',
#  'ఈ సినిమా ప్రపంచ వ్యాప్తంగా భారీ విజయం\n\nసాధించినందుకు చాలా ఆనందంగా ఉంది 🤩❤\n\nఎన్టీఆర్ అన్న యాక్టింగ్ అంటే ఎంతమందికి ఇష్టం',
#  'పాటకు తన నటనతో ప్రాణం పోసాడు\n\nProud to be NTR fan 🔥🔥🔥🔥',
#  'భారతదేశం గర్వించదగ్గ నటుడు ఎన్టీఆర్ అన్న 😍 కొమరం భీమ్ 🌊\nproud to be NTR anna fans...💞',
#  'ఈ పాటలో ఎన్టీఆర్ నటన అద్భుతం ఇలాంటి నటుడు దొరకడం మన భారతదేశ సినీ పరిశ్రమ చేసుకున్న ఎంతో అదృష్టం ఇలాంటి మంచి సినిమాలు అందించిన రాజమౌళి గారికి ప్రత్యేక ధన్యవాదాలు',
#  'వీడియో సాంగ్ కి యూట్యూబ్ లో నేను పెట్టే ఫస్ట్ కామెంట్ ఇది..... because of that acting.... గొప్ప అనుభూతి... గ్రేట్ ఆక్టింగ్... నేషనల్ అవార్డ్ రావాలని కోరుకుందాం....❤️❤️',
#  'ఈపాటలో ఎన్టీఆర్ గారి నటన ఎంత గొప్పదో రామ్ చరణ్ గారి నటన కళ్ళతో పలికే హవా భావాలు అంతే గొప్పదే వీరి నటనకు హాట్సాఫ్🙏🙏🙏😍😍😍',
#  'NTR గారి నటనకి కళ్ళలో నీళ్ళు ఆగడం బయ్య..... 🙏🙏',
#  'మా నాన్న తరవాత ఎవరైనా నా దేవుడు ఉందంటే, అది నా ప్రాణం, నా ప్రపంచం, నా లోకం నా దేవుడు నా NTR అన్న......❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️',
#  '🙏ఎన్టీఆర్ నటన అద్భుతం రామ్ చరణ్ యాక్షన్ అద్భుతం కీరవాణి మ్యూజిక్ అద్భుతం సాంగ్ మహా అద్భుతం దేశం గర్వించదగ్గ సినిమా తీసిన రాజమౌళి ఒక అద్భుతం ఇది భారతీయ చలనచిత్రానికి గర్వకారణమైన మూవీ.. RRR 🙏',
#  'Sir. Sr. NTR గారి వారసత్వాoతో పాటూ నట విశ్వూపాన్ని కూడా అంది పుచచుకున్నారు మన jr. NTR ❤️ జై బాలయ్య..✊',
#  'మారుమూలన బతికే గోండు జాతిని. గోండు బెబ్బులి కొమురం భీముడినీ ప్రపంచానికి.చూపిన RRR టీం కి నా వృదయపూర్వక. కృతజ్ఞతలు. మన అన్న ntr..నటన చూస్తుంటే రోమాలు నిక్కబొడుస్తున్నాయి 🤩🔥🔥🔥',
#  'No words at all....\nonly happy tears, we this generation blessed to see Jr.Ntr acting...\nHe z just stunner',
#  'మాటలు లేవు మాట్లాడుకోవడలు లెవు  పాట వింటుంటే చేతిపైన రోమాలు లేస్తున్నాయి ఈ పాటకు అవార్డులు రావాలని మనస్ఫూర్తిగా కోరుకుంటున్నాను జై NTR 🤩❤️❤️❤️',
#  'ఈ Song ఇప్పటికీ చూసిన goose Bams Vasthunnay❤️',
#  'నిన్న చూసి గర్విస్తుంది ఈ తెలుగు జాతి.. \nనీ మాటలు కురుక్షేత్ర యుద్ధం.. \nనీ చూపు వేటాడే పులి.. \nనీ నువ్వు చల్లటి గంగానది.. ',
#  'N.T.R.అనే ఒక మహా నటుడి కే ఇది సాధ్యం. అలాంటి గొప్ప వ్యక్తి గురించి,తన నటన గురించి వర్ణించడానికి మాటలు దొరకవు.jr N.T.R. Sir నిజంగా మీకు మా Salute.You  are such a legendary and finest 💯 complete actor in the INDIAN 📽️ cinema 🎥 sir.We feel proud about  you as a Telugu actor who is going to rule not only INDIAN cinema but also 🌎 WROLD 📽️. 💐💐🎉❤️❤️',
#  'Funny thing about this song is most of them doesn’t understand the lyrics but they connect with emotions 😊 That’s the power of emotions.',
#  'జీవితాంతం గుర్తుండిపోయే పాట 🔥❤️ఈ పాట కి Jr.Ntr అన్న చేసిన న్యాయం ఇంకా ఎవరు చేయలేరు. సింగిల్ పాట తో సినిమా డబ్బులు వసూలు అయిపోయింది జై Ntr జై జై Ntr🙏',
#  'నటన కి కూడా ఆశ్చర్యం అనిపించింది.... ఇంత అద్భుతంగా ఉంటాదా అని...ntr అన్న ..నీ అభిమాని అని గర్వపడుతున్నాను....జై NTR',
#  'భారత దేశంలో అత్యుత్తమ నటుడు....మా అన్న తారక్ ♥️ జై ఎన్టీఆర్',
#  'ఈ సినిమా ప్రపంచ వ్యాప్తంగా భారీ విజయం\n\nసాధించినందుకు చాలా ఆనందంగా ఉంది 🤩❤\n\nఎన్టీఆర్ అన్న యాక్టింగ్ అంటే ఎంతమందికి ఇష్టం',
#  'పాటకు తన నటనతో ప్రాణం పోసాడు\n\nProud to be NTR fan 🔥🔥🔥🔥',
#  'భారతదేశం గర్వించదగ్గ నటుడు ఎన్టీఆర్ అన్న 😍 కొమరం భీమ్ 🌊\nproud to be NTR anna fans...💞',
#  'ఈ పాటలో ఎన్టీఆర్ నటన అద్భుతం ఇలాంటి నటుడు దొరకడం మన భారతదేశ సినీ పరిశ్రమ చేసుకున్న ఎంతో అదృష్టం ఇలాంటి మంచి సినిమాలు అందించిన రాజమౌళి గారికి ప్రత్యేక ధన్యవాదాలు',
#  'వీడియో సాంగ్ కి యూట్యూబ్ లో నేను పెట్టే ఫస్ట్ కామెంట్ ఇది..... because of that acting.... గొప్ప అనుభూతి... గ్రేట్ ఆక్టింగ్... నేషనల్ అవార్డ్ రావాలని కోరుకుందాం....❤️❤️',
#  'ఈపాటలో ఎన్టీఆర్ గారి నటన ఎంత గొప్పదో రామ్ చరణ్ గారి నటన కళ్ళతో పలికే హవా భావాలు అంతే గొప్పదే వీరి నటనకు హాట్సాఫ్🙏🙏🙏😍😍😍',
#  'NTR గారి నటనకి కళ్ళలో నీళ్ళు ఆగడం బయ్య..... 🙏🙏',
#  'మా నాన్న తరవాత ఎవరైనా నా దేవుడు ఉందంటే, అది నా ప్రాణం, నా ప్రపంచం, నా లోకం నా దేవుడు నా NTR అన్న......❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️',
#  '🙏ఎన్టీఆర్ నటన అద్భుతం రామ్ చరణ్ యాక్షన్ అద్భుతం కీరవాణి మ్యూజిక్ అద్భుతం సాంగ్ మహా అద్భుతం దేశం గర్వించదగ్గ సినిమా తీసిన రాజమౌళి ఒక అద్భుతం ఇది భారతీయ చలనచిత్రానికి గర్వకారణమైన మూవీ.. RRR 🙏',
#  'Sir. Sr. NTR గారి వారసత్వాoతో పాటూ నట విశ్వూపాన్ని కూడా అంది పుచచుకున్నారు మన jr. NTR ❤️ జై బాలయ్య..✊',
#  'మారుమూలన బతికే గోండు జాతిని. గోండు బెబ్బులి కొమురం భీముడినీ ప్రపంచానికి.చూపిన RRR టీం కి నా వృదయపూర్వక. కృతజ్ఞతలు. మన అన్న ntr..నటన చూస్తుంటే రోమాలు నిక్కబొడుస్తున్నాయి 🤩🔥🔥🔥',
#  'No words at all....\nonly happy tears, we this generation blessed to see Jr.Ntr acting...\nHe z just stunner',
#  'మాటలు లేవు మాట్లాడుకోవడలు లెవు  పాట వింటుంటే చేతిపైన రోమాలు లేస్తున్నాయి ఈ పాటకు అవార్డులు రావాలని మనస్ఫూర్తిగా కోరుకుంటున్నాను జై NTR 🤩❤️❤️❤️',
#  'ఈ Song ఇప్పటికీ చూసిన goose Bams Vasthunnay❤️',
#  'నిన్న చూసి గర్విస్తుంది ఈ తెలుగు జాతి.. \nనీ మాటలు కురుక్షేత్ర యుద్ధం.. \nనీ చూపు వేటాడే పులి.. \nనీ నువ్వు చల్లటి గంగానది.. ',
#  'N.T.R.అనే ఒక మహా నటుడి కే ఇది సాధ్యం. అలాంటి గొప్ప వ్యక్తి గురించి,తన నటన గురించి వర్ణించడానికి మాటలు దొరకవు.jr N.T.R. Sir నిజంగా మీకు మా Salute.You  are such a legendary and finest 💯 complete actor in the INDIAN 📽️ cinema 🎥 sir.We feel proud about  you as a Telugu actor who is going to rule not only INDIAN cinema but also 🌎 WROLD 📽️. 💐💐🎉❤️❤️',
#  'Funny thing about this song is most of them doesn’t understand the lyrics but they connect with emotions 😊 That’s the power of emotions.',
#  'జీవితాంతం గుర్తుండిపోయే పాట 🔥❤️ఈ పాట కి Jr.Ntr అన్న చేసిన న్యాయం ఇంకా ఎవరు చేయలేరు. సింగిల్ పాట తో సినిమా డబ్బులు వసూలు అయిపోయింది జై Ntr జై జై Ntr🙏',
#  'నటన కి కూడా ఆశ్చర్యం అనిపించింది.... ఇంత అద్భుతంగా ఉంటాదా అని...ntr అన్న ..నీ అభిమాని అని గర్వపడుతున్నాను....జై NTR',
#  'భారత దేశంలో అత్యుత్తమ నటుడు....మా అన్న తారక్ ♥️ జై ఎన్టీఆర్',
#  'ఈ సినిమా ప్రపంచ వ్యాప్తంగా భారీ విజయం\n\nసాధించినందుకు చాలా ఆనందంగా ఉంది 🤩❤\n\nఎన్టీఆర్ అన్న యాక్టింగ్ అంటే ఎంతమందికి ఇష్టం',
#  'పాటకు తన నటనతో ప్రాణం పోసాడు\n\nProud to be NTR fan 🔥🔥🔥🔥',
#  'భారతదేశం గర్వించదగ్గ నటుడు ఎన్టీఆర్ అన్న 😍 కొమరం భీమ్ 🌊\nproud to be NTR anna fans...💞',
#  'ఈ పాటలో ఎన్టీఆర్ నటన అద్భుతం ఇలాంటి నటుడు దొరకడం మన భారతదేశ సినీ పరిశ్రమ చేసుకున్న ఎంతో అదృష్టం ఇలాంటి మంచి సినిమాలు అందించిన రాజమౌళి గారికి ప్రత్యేక ధన్యవాదాలు',
#  'వీడియో సాంగ్ కి యూట్యూబ్ లో నేను పెట్టే ఫస్ట్ కామెంట్ ఇది..... because of that acting.... గొప్ప అనుభూతి... గ్రేట్ ఆక్టింగ్... నేషనల్ అవార్డ్ రావాలని కోరుకుందాం....❤️❤️',
#  'ఈపాటలో ఎన్టీఆర్ గారి నటన ఎంత గొప్పదో రామ్ చరణ్ గారి నటన కళ్ళతో పలికే హవా భావాలు అంతే గొప్పదే వీరి నటనకు హాట్సాఫ్🙏🙏🙏😍😍😍',
#  'NTR గారి నటనకి కళ్ళలో నీళ్ళు ఆగడం బయ్య..... 🙏🙏',
#  'మా నాన్న తరవాత ఎవరైనా నా దేవుడు ఉందంటే, అది నా ప్రాణం, నా ప్రపంచం, నా లోకం నా దేవుడు నా NTR అన్న......❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️',
#  '🙏ఎన్టీఆర్ నటన అద్భుతం రామ్ చరణ్ యాక్షన్ అద్భుతం కీరవాణి మ్యూజిక్ అద్భుతం సాంగ్ మహా అద్భుతం దేశం గర్వించదగ్గ సినిమా తీసిన రాజమౌళి ఒక అద్భుతం ఇది భారతీయ చలనచిత్రానికి గర్వకారణమైన మూవీ.. RRR 🙏',
#  'Sir. Sr. NTR గారి వారసత్వాoతో పాటూ నట విశ్వూపాన్ని కూడా అంది పుచచుకున్నారు మన jr. NTR ❤️ జై బాలయ్య..✊',
#  'మారుమూలన బతికే గోండు జాతిని. గోండు బెబ్బులి కొమురం భీముడినీ ప్రపంచానికి.చూపిన RRR టీం కి నా వృదయపూర్వక. కృతజ్ఞతలు. మన అన్న ntr..నటన చూస్తుంటే రోమాలు నిక్కబొడుస్తున్నాయి 🤩🔥🔥🔥',
#  'No words at all....\nonly happy tears, we this generation blessed to see Jr.Ntr acting...\nHe z just stunner',
#  'మాటలు లేవు మాట్లాడుకోవడలు లెవు  పాట వింటుంటే చేతిపైన రోమాలు లేస్తున్నాయి ఈ పాటకు అవార్డులు రావాలని మనస్ఫూర్తిగా కోరుకుంటున్నాను జై NTR 🤩❤️❤️❤️',
#  'ఈ Song ఇప్పటికీ చూసిన goose Bams Vasthunnay❤️',
#  'నిన్న చూసి గర్విస్తుంది ఈ తెలుగు జాతి.. \nనీ మాటలు కురుక్షేత్ర యుద్ధం.. \nనీ చూపు వేటాడే పులి.. \nనీ నువ్వు చల్లటి గంగానది.. ',
#  'N.T.R.అనే ఒక మహా నటుడి కే ఇది సాధ్యం. అలాంటి గొప్ప వ్యక్తి గురించి,తన నటన గురించి వర్ణించడానికి మాటలు దొరకవు.jr N.T.R. Sir నిజంగా మీకు మా Salute.You  are such a legendary and finest 💯 complete actor in the INDIAN 📽️ cinema 🎥 sir.We feel proud about  you as a Telugu actor who is going to rule not only INDIAN cinema but also 🌎 WROLD 📽️. 💐💐🎉❤️❤️',
#  'Funny thing about this song is most of them doesn’t understand the lyrics but they connect with emotions 😊 That’s the power of emotions.',
#  'JR.NTR లాంటి హీరో ఉండటం టాలీవుడ్ మరియు తెలుగు ప్రజలు చేసుకున్న అదృష్టం 🙏🙏🙏',
#  'ఈ సినిమా ప్రపంచ వ్యాప్తంగా భారీ విజయం\n\nసాధించినందుకు చాలా ఆనందంగా ఉంది 🤩❤\n\nఎన్టీఆర్ అన్న యాక్టింగ్ అంటే ఎంతమందికి ఇష్టం',
#  'సుద్దాల అశోక్ తేజ గారి సాహిత్యం, ఎన్టీఆర్ గారి నటన నభూతో నభవిష్యతి... 👌👌👌',
#  'NTR base voice is vere level for this song.... Tears with goosebumps in theatre 😍😍😍',
#  'NTR అన్న నటన, రామ్ చరణ్ అన్న కళ్లల్లో బాధ అద్భుతం..👌👌',
#  'சூப்பர் பாடல் வரிகள் அருமை வாழ்த்துக்கள் ❤️ சூப்பர் NTR அண்ணா💞💞👍',
#  '👉💪పాట రాసిన సుద్దాల అశోక్ తేజ గారికి పాటకి ప్రాణం పోసిన  జూనియర్ ఎన్టీఆర్ గారికి ధన్యవాదాలు👍🙏🙏🙏🙏🙏👌💪',
#  'NTR 🙏🙏 If this performance doesn’t deserve National Award, then I don’t know what does!!',
#  'NTR Anna ki National Award  Ravali ani korukuntunna ❤️❤️❤️ from MB Fans ❤️❤️🌟🌟🌟',
#  'watching it for 67th time. wow what an amazing screen presence. After watching his acting I can feel the hard work they put in.',
#  'N : నటన లో\nT : తిరుగు లేని\nR : రారాజు.    \nదేశం మొత్తం గర్వించదగ్గ నటుడు దొరికి నందుకు మన తెలుగు వాళ్ళు గర్వ పడాలి జై NTR',
#  'NTR అద్భుతమైన నటనకు సెల్యూట్. ఈపాటలో NTR నటనకు జాతీయ అవార్డు కూడా తక్కువే.',
#  'కళ్లతో కూడా నటించే నటుడు తెలుగు వాడై ఉన్నడుకు నాకు చాలా గర్వంగా ఉంది . సంపూర్ణ నటుడు అనే పదానికి నిర్వచనం 🙏 . భారతదేశం గర్వించదగ్గ నటుడు ఎన్టీఆర్ అన్న',
#  'Whataah performance from Jr.NTR sir 🙏🏿🙏🏿 \nactually, getting emotional 😢 to all audience is not done by everyone but NTR sir did it well👍🏿  and also this NTR sir character is more harder 🥵\nEspecially hatsoff   to Rajamouli sir  for giving such a wonderfull  movie 🙏🏿 ',
#  'ప్రాణం పెట్టి చేశావు అన్న నీ నటనకు ఎన్ని అవార్డులు ఇచ్చిన తక్కువ అన్న జై NTR 🙏🙏🙏',
#  'சிறந்த பாடல் இந்த பாடல் எனக்கு மிகவும் பிடிக்கும்',
#  'Hats off to RRR movie team and special thanks to NTR garu for this marvellous performance',
#  'As a PSPK fan ga chepthunna NTR Anna your acting levels verayya 😭😭😭',
#  'ఇంకో 1000 సంవత్సరాల తరువాత సినిమా హీరో నటుడు అనే ప్రస్తావన వస్తే ముందు ఎన్టీఆర్ అన్న పేరే గుర్తుకు వస్తాది..🙏🙏',
#  'ఈ పాట వింటే కంట నిరు అగలేదు జై NTR 🙏😭🔥',
#  'ఎంత మంది కళ్ళల్లో నీళ్ళు తిరిగాయి\n\nJr.NTR నట విశ్వరూపం ❤️🧡🥰',
#  'NTR అన్న ఈ పాటలోని నీ నటనకి ఈ క్షణమే నీ అభిమానిని అయ్యాను',
#  'RRR NTR ELVVATIONS LEVU ANAARU.. EE SONG CHALUU🙏🙏 WHAT A PERFORMANCE ANNA GOOSEBUMPS SCENE 💥💥',
#  "India's greatest actor NTR ❤️👌 jai NTR Anna ❤️",
#  'In This Generation The Best Actor in India that is NTR, He deserves National Award for the Performance in this song...❤❤ Always Feel Proud as Your Hard Core Fan❤',
#  'THIS WAS AN EMOTIONAL SONG I AM PROUD TO BE NTR FAN',
#  'ప్రాణ స్నేహితుడి నమ్మకద్రోహం, చెల్లెలిని కాపాడలేకపోయా అనే బాధ, ప్రాణం పోతున్నా ఆత్మభిమానాన్ని, జాతి పౌరుషాన్ని ఆంగ్లేయుల బూట్లు దగ్గర తాకట్టు పెట్టకూడదు అనే పట్టుదల\nఇన్ని భావోద్వేగాలను కేవలం తన ముఖ కవళికలతో చూపించగలిగిన నటుడు అని గర్వాంగా చెప్పుకోగలం',
#  'I feel NTR and Charan has equal roles as per the story, subject and narration. But NTR ki role takkuva ani bhadapde  fans, ee song okati chalu aa Lotu Bharti cheyadaniki. Just watch and enjoy 😊',
#  "I Am Mega Family Hero's Fan But \nNTR SIR MIND-BLOWING PERFORMANCE FANS UNBELIEVABLE Action 🔥🔥🔥😎",
#  'NTR will get award for his acting. Superb mind blowing. Rajamouli extracted hidden talent in every actor ..',
#  'This song literally turned my enter emotion in theatre.... suddenly my eyes get wet... such a wonderful actor 🔥🔥 proud to be a fan of NTR ❤️❤️',
#  'నా అన్న NTR Career లోనే అద్భుతమైన పాట ఇది. తెలుగు ఇండస్ట్రీ లో మా NTR కి సాటి ఎవ్వడు లేడు ఇక రాడు.. Jai NTR',
#  'Jr. Ntr అన్న  ఈపాటకు తన నటనతో 100% న్యాయం చేశారు...థియేటర్లలో ప్రతి ఒక్కరి మనసును కలిచివేసిన పాట" కొమురం భీముడో"👍💐👌💐👍',
#  "Never give up ......bow to the leader's who fought for independence",
#  'ఈ పాట ntr కోసమే పుట్టినట్టు ఉంది ❤️😭😍',
#  'That energy...that emotions 🥺❤...love from Sri Lanka 🇱🇰❤',
#  "One of the greatest scenes🎥 along with the freedom speech song🇮🇳 in indian cinema. Goosebumps for sure I think most of them were cried after watching this song ❤️😢👌🏼JR NTR WAS NAILED HIS CHARACTER. AS WELL AS RAM CHARAN TOO👍🏼👌🏼 actually I don't know Telugu and I just want to know how fans will react in the comments!!",
#  'NTR ఒక అణీముత్యం , భారత దేశం గర్వించదగ్గ నటుడు ❤️',
#  'చాలా రోజుల నుండి ఎదురు చూస్తున్న పాట కొమురం భీముడు అద్భుతమైన చిత్రము NTR అన్న యాక్టింగ్ సూపర్ 🙏🙏🙏🙏🙏🙏🙏❤️❤️',
#  'Felt super proud as an NTR fan after watching RRR.\nAnd full marks to RC too.',
#  'చర్మమొలిచే దెబ్బకు ఒప్పంతోగాల..(తీవ్ర గాయాలకు తట్టుకోకపోతే కనుక)\nసిలికే రక్తం సూసి సెదిరేతోగాల.. ( రక్తం చూసి ధైర్యం చెదిరితే కనుక)\nబుగులేసి కన్నీరు ఒలికితోగాల.. (భయంతో కన్నీరు పెడితే కనుక)\nభూతల్లి సనుబాలు తాగనట్టేరో.. తాగనట్టేరో.. 🔥🔥🔥🔥🔥🔥 what a lyrics',
#  "Jr NTR sir , I don't understand telegu but your emotions in this song , i had goosebumps,,, u r brilliant",
#  'Every time I watch..it gives the same intensive goosebumps..No words to say for this epic song..',
#  'Ram charan eyes expression completely taking this song to another level 💥',
#  'Legendary song !!! Hats off to the Lyric writer, actors and director.',
#  'Rajamouli sir and most importantly Keeravani sir.. thanks a lot.. for giving us such a great visuals and this great emotional tune.. watched more than 200 times since yesterday.. OMG what a song and how beautifully carried out the emotions by NTR and Charan.. superbb...',
#  'ఇది ఒక పాటకోసం 8. సార్లు చూశాను..\nఈ మూవీ.. ఈ పాటలు ఎన్టీఆర్ తప్పితే ఎవరూ చేయలేరు..\nఎన్టీఆర్ అభిమాని గ పుట్టినందుకు\nగర్వపడుతున్నాను',
#  'ఈ ఒక్క పాట చాలనిపించిది అలా నటించారు NTR 👏👏👏🐯🐯',
#  'Historical Milestone Song in Indian Cinema..❤️💙\n\nNTR Sir.. ur Truly Blessed \nCharan Sir ur Maturity 🙏',
#  'This could be his BEST performace so far. Says so much with the eyes and words are just a consequence. \n\nBig fan of this scene',
#  "ఇదే song మా ఇంట్లో 2 years kid కి చూపిస్తే అలా చూస్తూ చాలా ఇన్వాల్వ్ అయిపోయింది😍 India's Greatest Actor",
#  'Jr ntr sir నటన చరిత్రలో నిలుస్తుంది 🌹🌹🙏🙏',
#  'ఈ పాట అంటే ఎంత మంది కీ ఇష్టం 💯🙏కేవలం ఈ పాట కోసమే 10 సార్లు చూసిన, ఎన్టీఆర్ నటనకు కంట్లో నీరు కరాయి 😭ఎన్టీఆర్ మీద రోజు రోజుకూ అభిమానం గౌరవం పెరిగిపోతోంది 💟💟🙏🙏💯👍',
#  '......NTR garu  meru mana indian and telugu vaaru ainanduku chalaa Garvamga undi proud of you 🙌🏻',
#  'Literally getting tears every time i watch him(jr.ntr) in this song \nEe okka janma kosam ntr anna fan ga garvam ga brathikestha',
#  'అన్నయ్య నీ మించిన నటుడు లేడు అని నా అభిప్రాయం ఈ పాట అన్నయ్య లేకపోతే సినిమానే లేదు',
#  'ఈ పాట చూసి నాకు చాలా బాధ వేసింది నాకు చాలా ఇష్టమైన పాట సూపర్ అన్న ఎన్టీఆర్ అన్న రాంచరణ్ యాక్టింగ్ బాగుంది',
#  'Mind blowing song ! Speaks to your heart. All in all - the best composition of Keeravani sir !',
#  'ఈ సినిమాలో NTR అన్న తప్ప వేరెవరూ ఎవరూ ఇంత మంచిగా Acting చేయలేరు...జై NTR🔥❤️',
#  'Greatest song for ever and ever in Telugu industry wonderful actor Jr NTR',
#  'ఎన్టీఆర్ మన తెలుగు చిత్ర పరిశ్రమకు చెందిన వ్యక్తి అని గర్వపడాలి JAI NTR',
#  'Hits differently in theatre 🔥🔥🔥\nGoosebumps for sure',
#  'Ee song lo NTR goosebumps ayithey Ramcharan acting emotional 😍🥰🥰🥰🥰🥰🥰🥰😍😍😍☺',
#  'Ram Charan acting also good in this song ..thana frnd ni kottaleka kottadam badha...badhyatha anni kalipi edusthu blood thuduchukodam scene highlight....NTR SUPER ACTING',
#  'What a song.......no words to Express of Feelings.......',
#  'Watched more than 100 times, still not bored, thank u ntr anna. Jai ntr',
#  'అద్భుతమైన పాట రాసిన సుద్దాల అశోక్ తేజ గారికి ధన్యవాదములు💐💐. ఇలాంటి  అద్భుతమైన చిత్రాన్ని తీసిన రాజమౌళి గారికి ధన్యవాదములు💐💐 RC🔥&NTR🔥',
#  'If there is an Oscar for "Best Cinematic Experience of the Decade", guess which movie truly deserves it?\n#RRR',
#  'Jai NTR Anna ........    Vere Level Performance ..👏',
#  'Ultimate Acting & Performance by Jr.NTR..Next Level at peak..Oscar for Jr.Ntr.. 👍👍',
#  'Rajamouli tells in Koffee with Karan about his taking and how he is the best in the country for showing emotions in actions. 4:29 onwards is a pure example of his capability to make you completely emotional followed by a high movement of people running to rescue the brutality..SSR has magic \U0001fa84 for sure 💯',
#  'పాట విన్నప్పుడు రోమాలు నిక్కబొడిచిన తెలంగాణ బిడ్డలు ఎంతమంది✊✊✊',
#  'ఈ పాట పాట చూస్తున్నంత సేపు నా కళ్ళలో కూడా కన్నీళ్లు తిరిగాయి.😥\nNtr🔥 నటన చూసి నాకు తెలియకుండానే నా  కన్నీళ్లు వచ్చాయి😥🙏\nNtr& Ram charan Acting🔥\nSS Rajamouli Direction🔥',
#  '😥😥😥😥😥😥😥😥ఈ పాట చూసినంత సేపు ఏడుపు ఆగలేదు సామీ😥😥😥😥😥😥😥😥😥😥😥😥💚NTR,,CHARAN💚అన్నల అద్బుతమైన నటనకుహ్యాట్స్ ఆఫ్❤❤❤❤❤❤',
#  "How many times I watched i don't know spectacular actor forever and ever really i appreciate NTR for giving this masterpiece to us \nnever give up his self-esteem",
#  'ఈ సినిమా మరో స్థాయి కి వెళ్లి నది అంటే because ee సాంగ్ వల్ల నే.....జై NTR ❤️❤️',
#  'NTR నటవిశ్వరూపం 💥... నభూతో నభవిష్యతి \nVersatile Person 🔥',
#  'Two stars in one movie 😎',
#  'NTR sir is the only one actor should carry  emotions, swag, attitude, acting🔥, dace 🔥',
#  'ప్రపంచం మొత్తం నీ నటనకు ఫిదా అయిపోయింది అన్నా..\nప్రపంచం మొత్తం గర్వించదగ్గ గొప్ప నటుడు N.T.R అన్నా.\nనీ అభిమాని అయినందుకు గర్వపడుతున్నాను ❤️',
#  'దీనిని మించిన సాంగ్ ఇక రాలేదు రాదు కూడా\nNtr... యాక్టింగ్ ఎవరు చేయలేరు \n    ❤🙏Ntr🔥💪',
#  'Tears on when we seeing this song... hatsoff to NTR anna',
#  'Mind blowing performance by jr.ntr..hats off to ur acting bro..',
#  'first famous and proud movie in the world 🤩🇮🇳🇮🇳',
#  'అన్నయ్య నీ నటన కి ఆ తెలుగు కళామతల్లి పులకించిపోతుంది 🙏🙏🙏💞💞💞జై ఎన్టీఆర్ 💞💞💞',
#  'Love from Kerala. My 3yo kid won\'t watch the Malayalam version. Whenever it plays he would ask for "Komuram bheemoodo". He know  most of the lyrics.',
#  'పాట రాసిన సుద్దాల అశోక తేజ గారికి, పాటకి ప్రాణం పోసిన ఎన్టీఆర్ నటవిశ్వరూపానికి జాతీయ పాట గాయకుడు కల్లా భిరైవా గారి కీ అవార్డులు రావాలని మనస్పూర్తి గా కోరుకౌంట్నాన్ను💗❣️❣️❣️✊✊✊👍👍👍💗💓❣️💖💝♥️♥️💝💝💝💝💝💖💖💖💖💖💖💖❣️💓❣️💓❣️💓💓💓',
#  'Believe me 0:01-5:44 goosebumps 💥',
#  'Long awaited for the performance of NTR and RC in the song "Komuram Bheemudo " was Awesome, Amazing 🤩❤...',
#  'చరణ్ లేకపోయిన  హిట్ అయ్యిద్ది, కానీ ఎన్టీఆర్ లేకపోతే హిట్ అయ్యేది కాదు. ఇది నిజం 🦁🦁',
#  "I'm waiting for this song..correct song for NTR ultimate acting looking forward to see him in another patriotic role 👏",
#  'ఈ పాట లో NTR నీ నటన మాత్రమే చూస్తున్నారు but Ram చరణ్ ఫీలింగ్స్ లో చూపించిన నటన సూపర్ ...',
#  'N- నటన లో\nT- తిరుగులేని\nR- రారాజు\nజై NTR ✊🐅🔥 జై జై NTR ✊',
#  'NTR with facial expressions and Ramcharan with eye expressions both lived in the characters, Kudos to Rajamouli garu for extracting such performance and special mention to singer,lyrisict, music',
#  'Ultimate acting by Jr NTR... Peaks of emotion...',
#  'The song which tested us.... The work we all put in to save ourselves from embarrassment, to stop crying, to hide those tears in theatre',
#  'Phenomenal acting by NTR',
#  'Ntr thappa inkka evvaru ee level lo acting cheyadam sadyam kadhu... Best indian actor present time... No words about his performance...',
#  'JrNtr annaya ఈపాటకు తన నటనతో 100% న్యాయం చేశారు థియేటర్లలో ప్రతి ఒక్కరి మనసును కలిచివేసిన పాట" కొమురం భీముడో" భారతదేశం గర్వించదగ్గ నటుడు ఎన్టీఆర్అన్న\n\nProud of be your fan #NTR anna😍',
#  'Enni sarlu chusina chudalanipinche song what a musicc #mm_keeravani \nActing of NTR sir in this song is really energetic ❣️ thank u for #khala_bhairava for this good one👍',
#  'ఒక్క పాట లో నవరసాలు పండించ  గల సత్తా ఏకైక నటుడు మా నందమూరి తారక రామారావు ఒక్కడే కే ఉంది .. I love you అన్నయ్య 💟🙏',
#  "After watching RRR movie, egarly waiting for this song. Wt an acting our young tiger 🐯 🙏🌹 NTR 🌹🙏\nNo words and no one can't do that massive performance 🙏🙏🙏",
#  'At 1:58, how many noticed the subtle act. Ram Charan wipes blood with his index finger and wipes a tear with his thumb. Poetic writing and placement 🔥🔥🔥',
#  'Jr NTR Expression Next Leval🥰🥰... NTR Blood.. Jai jai NTR',
#  'ఈ సాంగ్ రాసిన సుద్దాల అశోక్ తేజ గారికి అభినందనలు... అలాగే నందమూరి రామారావు గారి నటన అద్భుతం,అమోగముగా ఉంది.. కల్ల తోను అభినయ్ చేసే ఒకే ఒక్క హీరో యన్. టీ. ర్ \nఈ పాటలో ని ఎక్స్ప్రెషన్ వేరే లెవల్ కంగ్రాట్స్.',
#  'It is wonderful acting between Ram charan and NTR👏🏻👏🏻',
#  'ఈ పాటలో మీ నటన అమోఘం అద్భుతం అనిర్వచనీయం 🙏🙏🙏..',
#  'Next Level Song💥🔥(Superb Legend’s SS.Rajamouli, Jr.Ntr & Ram Charan)😎❤',
#  'NTR is best actor in Indian film industry...i love his acting from Student no1.',
#  "Rajmouli and Keervani's Magic duo begins at 4:30 😍",
#  'Always hearing this song really I said goosebumps r affected always',
#  'How many of u get tears on NTR performance 😥😥\nno words 💯💯',
#  'మీలాంటి గొప్ప నటుడికి అభిమాని గా ఉన్నందుకు గర్వ పడుతున్నాను అన్నా\nమీ నటనకు జాతీయ అవార్డు రావాలని కోరుకుంటున్నాను.\nజై యన్టీఆర్',
#  'Life long ntr best song never forget',
#  'ఈ పాటలో అన్న యాక్టింగ్ సూపర్ 😍😍😍\nజై ఎన్టీఆర్',
#  'The way they acted superb.speechless.',
#  'This song gives inspiration and never give up attitude in any situation 🔥🔥',
#  'Just a doubt.. How Delhi people understand this song lyrics to get motivated like this.. in previous sceens NTR itself used to speak in Hindi in this area.. logic missed I guess..',
#  'నటన అనే సామ్రాజ్యానికి ఏక చత్రాదిపతి మా NTR అన్న.............. Jai  NTR✊✊✊✊✊',
#  'One of the best performer in Indian cinema ❤️❤️',
#  'నీ నటనకి ప్రపంచం లో ఉన్న గొప్ప పురస్కారం కూడా చిన్న బోయింది అన్న!!!!\nనందమూరి పులి బిడ్డ 🐅🐅',
#  'Goosebumps ✊',
#  'Awesome song and mind-blowing action 🙏',
#  'Tollywood ka Baap\nKing of Indian Cinema\nNTR🔥🔥🔥',
#  'Thanks to RRR (Ram, Ramarao, Rajamouli) for showcasing the talent of Indians to the world',
#  'Jn NTR sir mi అద్బుతం అయినా నటనా కి మీకు ఎన్ని కోట్లు దండాలు పెట్టినా తక్కువే అండి 🙏😭my favourite song ❤️❤️🙏jn NTR sir గారిని కొట్టకండి రామ్ చరణ్ సార్ 😔',
#  'The most awaited movie before release, the most awaited song after release.',
#  'Waiting to see national award for this song 😘',
#  'NTR Anna Outstanding performance by komuram bheemudo RRR 🙏\nNational Award conform NTR❤🔥🔥🔥🔥🔥',
#  'ఒకొక word ki expression ఇవ్వడం ఒక NTR అన్న కే సాధ్యం...hatsoff 🙌🙌❤️ #NTR anna 🙏🙏🙏 చాలా మంది అమ్మలు కంట్లో నుండి కన్నీళ్ళు పెట్టించవు 🙏 #JaiNTR ❤️❤️❤️',
#  'ఎప్పటి నుంచో ఎదురుచూస్తున్న సాంగ్ కొమురం భీముడు, థియేటర్ లో ఎన్టీఆర్ అన్న నటన  అద్భుతం, చూస్తున్నంతసేపు కన్నీళ్లు ఆగలేదు.  రాజమౌళి గారి డైరెక్షన్,సుద్దాల అశోక్ తేజ గారు రాసిన పాట, కాలభైరవ పాడిన పాట ఒక అద్భుతం, ఇలాంటి సాంగ్ మళ్ళీ వస్తుందో రాదో చరిత్రలో',
#  'Jr.NTR literally lived the moment',
#  '@1:59, 4:31, 5:21 these scene Are goosebumps 💥',
#  'Oscars level performance of NTR Anna 🔥🙏🐅💙( nee tharvatha evarina acting dance  lo)❣️🌟💖💫',
#  'NTR action and Ram charan Reaction tho song inka highlight ayindhi💥💥',
#  'RRR Is Masterpiece.❤❤❤',
#  'NTR sir\nయాక్టింగ్ సూపర్ 🙏🙏🙏.\nమి యాక్టింగ్ కి రోమాలు నిక్కబొడుచుకుంది.💚🙏💚🙏',
#  'ఎన్టీఆర్🌊 మరియు రాంచరణ్🔥 ను కలిపి  చూపించడం  అనేది ఒక కళ దానిని సరిగ్గా చూపించారు రాజమౌళి గారు💙💚❤',
#  'Ntr acting and character is ultimate.he is like jesus in song',
#  'NTR. What a performance bro 🔥😎🔥',
#  'Jr NTR తన నటనతో  మనల్ని మంత్రముగ్ధుల్ని చేసాడు 💯💯💯💯\nకొమరం భీముడో',
#  'One of the finest actors in India jai ntr',
#  '1:41 goosebumps💥💥💥💥',
#  'Tollywood ka Baap\nKing of Indian Cinema\nNTR🔥🔥🔥',
#  'Song with beautiful lyrics and performance.',
#  'మా అన్నయ్య యాక్టింగ్ 👌\nనా కళ్ళలో నీళ్లు వస్తున్నాయి\nమన అన్నయ్య ఫ్యాన్స్ Like వేసుకోండి 👍\nజై NTR ❤️',
#  'Everyone is talking about eyes and expressions but what was incomprehensible for me was the way his body reacted for every lash and shiver he created just before the fall is unfathomable for me.',
#  'Jai NTR what a performance sir 👏👏👏🙏🙏👍👍👍👍👍👍👍👍👍👍👍👍',
#  'What a performance \nNTR deserves national award',
#  '😎ఎవత్ భారతదేశం నీకు సలామ్ కొడుతుంది✊\nనీ అభిమాని అని చెప్పుకోవడానికి చాలా గర్వంగా ఉంది అన్నయ్య 😍🔥 జై NTR అన్నయ్య 🔥\n😍LOVE YOU ANNAYA😍',
#  'Long waited for this song …..😍 no words to describe this song expressions and feel 🥰🥰😍',
#  'I am a tamilian but when I see this song feeling proud to be a Indian ....We are one nothing will separate us .....',
#  'THANK YOU SS RAJAMOLI SIR FOR THIS MOVE 🙏',
#  'పాట వింటుంటే రక్తం కుతకుతలాడుతుంది,, ఒక్కో దెబ్బకి 100మంది బ్రిటిష్ గాల్లని చంపలనిపిస్తుంది.. మేరా భారత్ మహాన్👳',
#  'Never ignore a person who loves you, cares for you, misses you. Because one day, you might wake up from your sleep and realize that you lost the moon while counting the stars💝',
#  'రాజమౌళి + రామ్ చరణ్ + రామా రావు = తెలుగు గెలుపు.\nఈ జన్మ కి ఇది చాలు. 🙏',
#  'waited for this song like ever . Finally arrived . Best song , acting , screen play . when best of best people collaborate miracles like this happen',
#  'ఈ పాటలో ఎన్టీఆర్ నటించాడు అనడం కంటే ప్రాణం పెట్టి జీవించాడు అనడంలో సందేహంలేదు ఒక్క పాటతో అందరినీ కంటతడి పెట్టించాడు ❤️👌❤️',
#  '1:42 నట సంహరుడు నంద మురి తారక రామ రావు అన్న గారికి హాట్స్ ఆఫ్ 🙏🙏🙏',
#  "Inspiration comes from within yourself. One has to be positive. When you're positive, good things happen. 💕",
#  'ఇంతా అద్భుతమైన పాట అందించినా \n #RRR  టీమ్ కు ధన్యవాదములు \n🔥✊🌊   💐💐💐',
#  'The greatest song ,I have not heard in my life.\nThanks , thanks south industry .',
#  'Outstanding Performance by Jr.NTR & Ram charan',
#  'Tollywood ka Baap\nKing of Indian Cinema\nNTR🔥🔥🔥',
#  'Goosebumps 🔥',
#  "This song deserves 2 National awards, 1st for Lyrics and 2nd for Tarak's intense&emotional performance....",
#  'NTR ji look kills all people hearts and this is very emotional song forever and ever. 🙌👏🙌',
#  'I am from Sri Lanka. Today my country is in danger too. The Rajapaksas are destroying Sri Lanka. We started to struggle. We were hit hard yesterday. But we will not stop. Our Prime Minister has resigned. He is the eldest in the Rajapaksa family. We will fight until the President resigns. Congratulations to Sri Lanka. ජය ශ්\u200dරී ලංකා...❤️🇱🇰💪',
#  'Jr NTR is the best ever!! Such a wonderful actor....',
#  "He deserves national award for this movie especially for this song.we can't imagine any other actor to do like this. ACTING synonym NTR 😍😍😍all the best NTR garu for upcoming movies",
#  'Excellent song..excellent emotion..wonderful taking..',
#  'NTR GARU DESERVES NATIONAL AWARD FOR THIS SONG .HIS ACTING 🔥🔥🔥🔥🔥🔥🙏🙏🙏🙏🙏👏👏👌👌👌👌👌...',
#  'I love this song 🥺🥺💗💗💗',
#  'భారతదేశం గర్వించదగ్గ నటుడు #నందమూరితారకరామారావు ( jrNTR) ఈ పాటకు ప్రాణం పోశారు... జై ఎన్టీఆర్..😍😍',
#  'What an amazing song. Amazing lyrics and amazing acting 👏 👌 😍  ....',
#  'Abbabba enti swamy aa acting NTR anna tollywood no1 actor.no one can replace his acting 💞 🔥🔥🔥🔥🔥🔥🔥🔥',
#  'All time favourite song and jai ntr acting heart touching all people jai NTR jai RRR❤️',
#  'NTR గారి నటనకు అభినందనలు. చాలా అద్భుతంగా ఉంది. ఈ పాట కు నూటికి నూరుపాళ్లు న్యాయం చేశారు యాక్టింగ్ తో. జక్కన్న గారూ మీకు సెల్యూట్ సార్.',
#  'Finally arrived most awaited video song.. edi kadha acting ante pure acting stuff ❤❤❤❤.  jai ntr',
#  'Proud to be a ntr Anna fan 😘😘❤️',
#  'ఈ ఒక్క పాట తో ని నటన గురించి , ని గురించి ప్రపంచం మొత్తం మాట్లాడుకునేలా చేశావ్ అన్న❤️❤️🙏🙏💥💥\nProud to be a NTR Anna fan❤️❤️🙏🙏',
#  'NTR one of the greatest Actors in Indian cinema 🙌',
#  'This song proved no one can acts like NTR, ntr dominate rc and rajamouli',
#  'Tollywood ka Baap\nKing of Indian Cinema\nNTR🔥🔥🔥',
#  '4:34 goosebumps🔥🔥🔥🔥',
#  "JrNTR fans ఎవరైనా కళ్ళు చమర్చకుండ ఈ పాట చూడలేరు Emotinol Connection between Their Fan's\nThat's NTR.",
#  'పాట కోసం ప్రతి రోజు యూట్యూబ్ లో సర్చ్ చేస్తున ఈరోజు వచ్చినందుకు ఆనందంగా ఉంది అన్న ఆక్టింగ్ సూపర్ big fan of A A  😍🔥',
#  'As a Prabhas fan I am sincerely hoping to get a National Award for Tarak anna performance in this movie, especially in this Song🔥🔥🔥👏👏👏👏',
#  'NTR Next level Acting in Tollywood. \nHe has great acting skills',
#  'The komaram bheemudo song is one of the hallmarks of RRR🔥. No other Indian actor can do what NTR did in this song✊ . There is rage , there is emotion, and there is pain .NTR expresses all these intense emotions in one shot . This is the epitome of Acting ♥️🔥\n                ~ SS Rajamouli 💕',
#  'మా అన్నయ్య NTR గారి నటనకు ఎవ్వరైనా ఫిదా ఆవలసిందే...... 😭😭',
#  'Supb acting by NTR anna❤💥.. Box office recordlu motham breake....bgm , singing are mind blowing 😍😍',
#  'I love this song mind blowing',
#  'ఈ సినిమా ఇప్పటి వరకు చూడలేదు భయ్యా నేను... కానీ ఈ పాట చూడిన తర్వాత ఎందుకు చూడలేదు అని గిల్టీ ఫీల్ అవుతున్న..  NTR గారి యాక్టింగ్ 👌... Vere level',
#  'Ntr sir acting .\nKi just goose bumps.\nAnd ramcharan also performed very well in this song\nBut NTR SIR ..',
#  'Charan & NTR... Thsnks... You both made us proud...Love u both',
#  'సూపర్ సాంగ్ ఇలాంటి పాట తెలుగు సినీ పరిశ్రమలో ఎప్పటికీ మర్చిపోలేని ది గ ఉంటది ntr నటన అద్భుతం',
#  "Brothers both are best friends don't fight we are all Tollywood lovers  JAI NTR ANNA JAI RAMCHARAN ANNA\nJai Hind",
#  'ఎన్టీఆర్ అన్న నటన మహాద్భుతం ఈ పాటలో తన నటనకు తగిన న్యాయం చేసాడు ఈ ఒక్క పాటవల్ల ఈ సినిమాకె జీవం పోసాడు జయహో ఎన్టీఆర్ అన్న 🙏🙏',
#  'NTR KILLED THIS SONG WITH HIS EXPRESSIONS.......',
#  "I respect everyone who were involved in this , Seriously the best piece that I' ve ever seen on YouTube ,HATS OFF TO WELL ALL ! LOVE YOUR VIDEOS !!!!😷😇",
#  'really love the scene, too emotional',
#  'Whole movie story is in single song. Hatsoff to writer suddala ashok sir.',
#  'Tollywood ka Baap\nKing of Indian Cinema\nNTR🔥🔥🔥',
#  'Epic song 🎵 and performance of both actors',
#  "1:43 this shot is just insane it made me emotional and thousand emotions flowed through me during this song i can't forget the experience i had seeing this movie. This song is not just a song it's a glimpse of acting calibre of NTR and RC. RRR is truly a festival 🔥❤️",
#  'One of the best actor in telugu industry hatts of tarak anna💘💘💘💕',
#  'You are just awesome NTR ❤️',
#  'NTR. ❤️\nRAM. 🔥 Both are super actors....😍',
#  'Feel never change దియేటర్ లో చూసినప్పుడు ఎలా ఉందో యూట్యూబ్లో చూసినప్పుడు కూడా అలాగే ఉంది same feel.👌👌👏👏🙏🙏',
#  'It brought tears in my ears in the hall, especially the last scene.',
#  "Ntr's performance throughout the song is very impressive.\nRRR fans 💥💥💥",
#  "I couldn't help with crying, hatsoff NTR sir",
#  'నువ్వు పుట్టింది నటన కోసమే అన్న... ఈ సాంగ్ చూసి ఎంత మంది ఏడ్చారో... కన్నీళ్లు పెట్టుకున్నారు',
#  'Really cried while watching what an acting by ntr anna lived in bheem character',
#  'సుద్దాల అశోక్ అన్న పాట తో...నల్గొండ నెల తల్లి పరిమలిస్థుంధి...జై తెలంగాణ',
#  'Jai NTR Jai Ram Charan 😍😍',
#  'That intense eyes of Ramcharan! It can tell you thousands of stories 🔥🔥🔥',
#  'ఎన్టీఆర్ నట విశ్వరూపం...🔥🔥',
#  'ఆస్కార్ అవార్డు నటన కనపరిచిన మన jr. ఎన్టీఆర్ అన్న కి... నా శతకోటి వందనాలు.....',
#  "I had tears in my Eyes in theater....🥺Now I'm feeling very Proud while watching this  Song.... 💥🙏Proud to be NTR fan Always....🐯🐅❤️",
#  'Super song 😍🤩🤩',
#  'The whole movie was taken by tarak in one song❤❤❤❤❤❤❤',
#  'Tollywood ka Baap\nKing of Indian Cinema\nNTR🔥🔥🔥',
#  'Cinema anta oka level but e song n our own NTR acting verea level! \nNTR the complete actor..',
#  "5:22 this shot took my heart way man it's just perfect 🔥🔥 RRR is not just a movie it's a festival for us. I am a northern guy and i just loved this movie a lot 🔥❤️",
#  "Everyone will definitely appreciate ntr's marvelous performance in this song... But take a moment and applaud RamCharan's acting too who had to blend aggression in his actions and sympathy in heart conveyed through his eyes....",
#  "A moment of silence for those of who still haven't found this MASTERPIECE SONG...",
#  'Proud to be a ntr gari fan ❤️❤️❤️',
#  '1:38 to 1:54 Pride, Anger, Betrayal, Helplessness, Pain, all emotions in one expression. #NTR',
#  'ఈ సినిమా లో  రామ్ చరణ్, NTR  Acting గురించి ఎంత చెప్పినా తక్కువే 👌👌👌🥰🥰',
#  '....song la first nunchi last varaku Goosebumps anna 🙏',
#  'Visuals, Music, Singing, Direction, Slo-Mo Shots, Angles, Cinematography, Editing and of course That ACTING...... Pure Cinematic Brilliance.',
#  '❤  jai  ntr ❤️   jai  rrr  ❤️',
#  'NTR is once in a life time..I am proud to be contemporary to NTR. I AM LIVING ON THE LAND WHERE NTR WAS ALIVE AND BREATHING.🙏🙏🙏🙏🙏',
#  'Stunning performance👏👌...my favorite from mahesh fan',
#  'ఎన్టీఆర్ తన అభినయంతో ఎంత చెయ్యగలడో... ఎమ్ చెయ్యగలడో ఈ ఒక్క పాటతో చూపించాడు...\nఎటువంటి పాత్రకైనా తన అభినయంతో న్యాయంచేయగల అద్భుత నటుడు ఎన్టీఆర్',
#  'కెమెరా కోసం పుట్టిన నటుడు..\nజనాల్లో చలనం తీసుకురాగల మహానటుడు.. ఎన్టీఆర్',
#  '40% ntr and 60% rc roles were given to them yet ntr and him expressions were 😍😍 yet I love the rc as ramudu',
#  'Movie mothaniki NTR acting highlight 🔥🔥🙏🙏🙏',
#  'What a song \nWhat a actor \nWhat a performance \nKudos 👏  to NTR..',
#  'ప్రపంచం గర్వించదగ్గ మహా నటుడు మన తారక రామారావు NTR అన్న',
#  'మా అన్న నటన కి పాదాభివందనం..... 🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏🙏',
#  'Tollywood ka Baap\nKing of Indian Cinema\nNTR🔥🔥🔥',
#  "Can't understand Telugu , but this song is one of my favourites from Telugu movies",
#  'నీ నటన తో\nఈ సినిమా టాప్ లేచిపోయింది అన్న 🔥🔥🔥💐💐🎉\nజై NTR 🔥 న',
#  'నందమూరి తారక రామారావు నటన అద్భుతం మీ నటనకు బాంచన్ అయితేనే అన్న',
#  'Heart touching song 💘 super lyrics',
#  'ಅದ್ಭುತ.. ಹಾಗೂ ಅಮೋಘವಾದ ಹಾಡು.. ಕಲೆಗೆ ಜಯವಾಗಲಿ 🙏',
#  "There's no other actor could've protrayed this character as good as tarak sir, he's the best...\nJai Ntr...💪❤👌",
#  'అన్నయ్య నీ నటనతో అందరికి కన్నీళ్లు తెప్పించావ్.',
#  'Mind blowing song....,❤️❤️❤️\nJai NTR anna...',
#  'Jai NTR ANNA 🙏🙏💪',
#  'We are soo proud to be INDIANS',
#  'Give this Man a  Oscar For this Performance ♥️♥️ #RRR',
#  'Ee song lo ram charan expressions vere level🔥🔥🔥\nMega power star 🥰',
#  'Ramcharan ji is to good and perfect both are the best actors. 🙌👏🙌',
#  'The Best.. In this movie 💐💐💐💐',
#  'Rakhee railway station seen ,temper court seen and this song is all-time outing perfomance to NTR sir 👌',
#  'Tollywood Tiger NTR\nBollywood ka Baadshah NTR\nKing of Indian Cinema NTR🔥🔥🔥',
#  'ఎందుకో తెలీదు ఈ సాంగ్చూస్తుంటే కళ్ళల్లో నీళ్లు కారుతున్నాయి, కచ్చితంగా నేషనల్ అవార్డు వస్తుంది ఈ సాంగ్ కి,నీ అభిమాని గా పుట్టినందుకు గర్వం గా ఉంది ఎన్టీఆర్ అన్న, జై ఎన్టీఆర్ అన్న 🙏🏼🙏🏼👌🏼👌🏼😭😭',
#  'ఈ పాట పాట చూస్తున్నంత సేపు నా కళ్ళలో కూడా కన్నీళ్లు తిరిగాయి',
#  'ఈ ఒక్క సాంగ్ చూస్తే చాలు టెంపర్ ఫుల్ మూవీ చూసినట్టు ఉంది.. ❤️u NTR anna',
#  'Tollywood ka Baap\nKing of Indian Cinema\nNTR🔥🔥🔥',
#  'Thank you so much upload this song NTR anna super mass performance expression never ever re-create this place jai NTR anna',
#  'Everybody after listening to the song will definitely get Goosebumps or tears for sure... ❤️❤️ #jaiNTR 🔥',
#  'Best performance by my NTR till date, salute \U0001fae1 \U0001fae1 \U0001fae1',
#  '1billion song Goosebumps every scene 👌👌👌',
#  "It's really fantastic song. Most sentimental ever.👌👌",
#  'Jai RamCharan 💥🦁💪',
#  'ఈ సాంగ్ ఒక్కటీ చాలు Jr NTR యాక్టింగ్ ఏంటో తెలుస్తుంది... ఫ్యూచర్ లో ఎనో అవార్డ్స్ వచ్చి చేరుతాయి ......',
#  'One of the heart touching song',
#  'Emotional song 💚',
#  'జై తారక్ అన్న 😍😍😍',
#  'Superb song 👌👌',
#  'Jai Rajamouli,jai NTR',
#  'This song 🤩makes the indian actors proud 🔥🔥🔥\nProud to be an Indian \nJai ntr🤩\nLove this song ❤❤❤',
#  'Brilliant performance by Nandamuri Taraka RamaRao .. Excellent Anna .. You Nailed it.',
#  'అద్భుతమైన పాట.\nఅద్భుతమైన నటన.',
#  'కల్వరి సిలువ పై తన చివరి రక్తపు బొట్టు వరకు విడిచిపెట్టి మన పాపాలను తన రక్తంతో శుద్ధి చేశాను',
#  'మొదటగా ఈ పాటని విడుదల చేయాలి ...కానీ ఇన్ని రోజులు పట్టింది ఏది ఏమైనా ఈ పాట కి మాత్రం నా జోహార్లు ✊✊✊\nఎన్టీఆర్ గారి నటనా రాం చరణ్ నటన మాత్రం చాలా అద్భుతంగా ఉంది ...🤗🤗 🤝',
#  'This is giving Same high what it gave in theatres🔥🔥🔥',
#  'Hats off to you Rajamouli Sir great respect from Kurnool',
#  'Tollywood ka Baap\nKing of Indian Cinema\nNTR🔥🔥🔥',
#  'I like the telugu version of this song the most.',
#  'Wt a పెర్ఫార్మన్స్ 💥💥💥, wt a actor, ఎన్టీఆర్ deserve for best యాక్టర్ award 💥💥💥💥',
#  'AWESOME expressions by our fav ntr 🤙🤙🤙',
#  'No words 🙏🙏🙏🙏🙏 goose bumps only 🔥🔥🔥🔥🔥🔥🔥🔥💫🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥 🔥',
#  'The power true INDIAN🇮🇳 jai hind.,',
#  'Tears while watching jai ntr 😭',
#  'Jai Ntr.... Jai Ho Ntr 🌊🇮🇳',
#  'Jai bheem ఈ song 🥺🥺🥺  movie ki పెద్ద హిట్ ఇచ్చింది జై ntr జై రామ్ 🌊🌊🌊🔥🔥🔥.',
#  'Song of the century🔥🔥🔥🔥',
#  'NTR 🔥\nWhat action bro\nMind blowing performance',
#  'Super movie super song heart touching 👍👍👌👌👏',
#  "epic, i have not seen this kind of performance in an other movies till now.  In tollywood we have so many better hero's it hard to select one.",
#  'ఎన్ని సార్లు చూసినా మరి చుడాలని అనిపించె నవరస నటనకు N(నటనలో)T (తిరుగులేని) R (రారాజు) కు జే జెలు',
#  '4:30 the moment when the song made my tears roll down & gave instant Goosebumps!🤝🇮🇳♥️',
#  'Been waiting for this song! #JrNTR is the best❤️❤️❤️❤️',
#  'Iam feel proud to be a ntr fan💥',
#  '5:22 This shot is just universally epic. Gives ultimate goosebumps 🔥❤️❤️',
#  'NTR Anna Acting Award Winning Performance',
#  'సూపర్ పాట అన్న ఈ పాట కు దాసోహం ఎన్టీఆర్ అన్న నీ ఎక్స్ప్రెషన్ అద్భుతం వందనాలు నీకు🙏🙏',
#  'Tollywood ka Baap\nKing of Indian Cinema\nNTR🔥🔥🔥',
#  'How many times I heard this song... Same new felling',
#  'మీ లాంటి గొప్ప నటుడికి అభిమానిగా ఉన్నందుకు నేను చాలా గర్వపడుతున్నాను నీ మీద ఉన్న అభిమానం తో నాకు పుట్టిన కొడుకు కి నీపేరు తారక రామారావు అని పెట్టాను అన్నయ్య.',
#  '4:32 goose bumps unlimited 🔥🔥🔥',
#  'what a wonderful song',
#  'Heart touching Song...🙏🙏🙏🙏',
#  "Movie super.... RC NTR Anna's acting veraalevel ....🔥🔥🔥🔥🔥🔥",
#  'Love from kerala ♥️♥️♥️♥️♥️by a keeravani fan♥️♥️♥️',
#  'I love this song and also ntr',
#  '04:50  Tears comes from the heart not from the eyes !! 🔥🌊 కన్నీళ్ళు గుండెల్లొ నుండి వస్తాయి, కళ్ళలో నుండి కాదు',
#  'GOOSEBUMPS ❤❤❤❤❤ 5:44 MINUTES',
#  'My favorite song 🎵 ❤ 💕',
#  'Goosebumps moment',
#  'Everyone got tears while this song is playing',
#  '4:31 Movement Goosebumps',
#  "1:44 just look at this scene it will make u emotional and motivated this song is so much special for me coz its not just a song it's an universe of NTR acting and expressions",
#  "Watching repeatedly can't stop tears  in my eyes 👏🌊👏",
#  'As a Mahesh babu fan ga cheptunna NTR ni acting lo kottetodu e Telugu film industry lone ledu 😍😍😍😍',
#  'Ntr great sir \nIn India your are one and only person in acting dance \nWhat a expression\nI proud to say I am fan of NTR',
#  'No one can beat in acting compared to NTR. Great.....',
#  'Ntr and Ramcharan 👏👏👏👏👌👌👌👌',
#  'E song ki character undi babaii  aa character peru   NTR❤❤',
#  'Jai NTR ❤️',
#  'No words\nOnly NTRC❤️\nGoosebumps🔥',
#  "I belong to marathi background and don't know telugu but I felt cry whenever I listen this song🙌😭😭😭",
#  'Both actors  acting  super  and both  expressions  is excellent  on both creators  demands',
#  'జై ఎన్టీఆర్ అన్న',
#  'The time the entire nation realized the acting potentiality of the actor NTR.',
#  'Big Salute to NTR Sir',
#  'No words super song 👌👌👌👌👌😭😢 Oscar level performance🤩\nProud of to be ntr fans❤️',
#  'ఏమని వర్ణించలేము ...తారక్ అన్న విశ్వరూపం అత్యద్భుత దృశ్యరూపం....',
#  'NTR Annayya acting superb ❤️👌',
#  'అన్నయ్య కి ఆస్కార్ అవార్డు ఇవ్వాలి అని నా కోరిక ఎన్టీఆర్ అభిమానిగా',
#  'Ram charan acting also superb. Face feelings 🔥',
#  'I love my country “HINDUSTAN”',
#  'I just love 2 expressions of NTR in #RRR\n1. Komaram bhemudo song \n2. Ram Charan banam pettina scene ( Alluri Sitaramudu scene) water lo unnapudu NTR eche expression  ♥️',
#  'Charan acting pure in it... Oka vaipu sneham oka vaipu laksham.. great balanced sir... Hats off🤐🤐🤐',
#  'Never before ever after from NTR ..... Fantastic expressions',
#  'Chills, Literal chills!',
#  'Best song jai NTR',
#  '🔥🔥🔥Jai Charan Jai NTR🔥🔥🔥',
#  'సూపర్,  జక్కన్న చెక్కిన శిల్పం  మన jr బాబు,ఈ ఒక్క సాంగ్ చాలు  * పాన్ ఇండియా ని తిరగ రాయడానికి ,అమోఘం,అద్భుతం, tq s s Rajamouli sir.',
#  'Jai NTR 🙏🙏🙏🙏🙏',
#  'No one can match NTR in this song......... 😍🥺😍🥺😍🔥',
#  'అన్నా నటనలో నీ తర్వాతే ఎవరైనా మన తెలుగు ఫిలిం ఇండస్ట్రీ శభాష్ అని  చెప్పుకునే ఒక గొప్ప నటుడు అన్నా మీ నీకు అభిమాని అయినందుకు గర్వపడుతున్నాను జై NTR ✊',
#  'నటనలో నందమూరి కి సాటి రారు ఎవ్వరు.. జై ఎన్టీఆర్ 🙏🙏🙏',
#  'EMI acting Chesav Annayya Proud of Ur Fan loveeee Uuuuu Annayya 😍😍❤❤\nChickaballapura NTR Fans❤❤ Jai NTR Jai Jai NTR 🔥🔥🤙🤙',
#  'సుద్దాల అశోక్ తేజ గారికీ ధన్యవాదాలు  ఈ పాట అద్బుతం ntr నటన అద్భుతం.',
#  '🙏🏻🙏🏻🙏🏻jai NTR annayaa 🔥🔥🦁',
#  'నేను ఎన్టీఆర్ అభిమాని అయినందుకు గర్వం  పడుతున్నాను 💯❤',
#  'NTR acting..hatsoff...waiting for this song from many days for NTR 🔥🔥',
#  'సూపర్ సాంగ్ సూపర్ యాక్టింగ్ అన్న సాంగ్ చూస్తుంటే ఏడుపు వచ్చేస్తుంది అన్న',
#  'I love this song',
#  'తెలుగుజాతి గర్వించే ల నీ నటన అద్భుతం ఇలాంటిది ఎప్పటికీ మాకు గుర్తుండిపోయేలా చేసావ్ అన్న నీ కాళ్లకు బాంచన్ ఏ జై ఎన్టీఆర్ జై జై ఎన్టీఆర్ 🙏🙏🙏',
#  "The intensity in charan's eyes, and tarak's acting made this song too emotional",
#  '#Evergreen Milestone Performance In Indian Film Industry 🥺💥❤️ #Jai NTR Annayya 🔥💥❤️',
#  'Ntr anna acting vere level 🔥',
#  'No item songs\nNo vulgar language\nNo sexist dresses\n100% patriotic emotions!',
#  'What a actor Jr NTR....🔥🔥🔥',
#  'Charan did an excellent job... The intensity in his eyes, his attitude everything is just perfect...',
#  'Super song video\nJai NTR\nRam Charan',
#  'Mind blowing song.',
#  'Big fan for this song',
#  'Oscar performance.. 💥🔥🔥Jai Ntr Anna🔥🔥🔥🔥🔥🔥🔥',
#  'I love this song',
#  'The most awaited song 😪😪 #NTR _Anaa❤❤',
#  'ఎన్టీఆర్ చాలా బాగా నటన చేశాడు',
#  'Most awaited song in my life',
#  'Super song, in national award in song , jr ntr action ultimate 🔥🔥🔥',
#  'carrier best performance by \nNTR 😍🔥🔥\nJai NTR ❤️💥💥💥💥💥',
#  'NTR కరీర్లో బెస్ట్ సాంగ్ ..సూపర్ యాక్టింగ్ అన్న',
#  "Marvelous acting by tarak anna can't blink a eye for a sec annaya love u all the time",
#  'RRR IS VERY GOOD &GREAT MOVIE \nJAI JAI SS RAJA MOULI SSSSSSSSSSSSSSS jai NTR. JR.)JAI JAI RAM CHARAN, JAI HANUMAN 👌👌👌👌👌👌👌👌👌👌👌👌👌👌👌🦜🦜🦜🦜🦜🦜👌👌👌👌👌',
#  'Awesome performance 💖',
#  'Jai ntr😍😍😍😍😍😍😍😍😍😍😍',
#  'ఎన్టీఆర్ అన్న నటనకు కన్నీళ్లు వస్తున్నాయి\nజై ఎన్టీఆర్...',
#  "Ntr did great 👍\nBut Ram Charan also acted very well in this song you know he is on mission to give weapon to every hand in his village a promise taken from his father by A Ramaraju...\nReason why he's  comply with scott and  beating Bheem  ruthlessly ",
#  'ఎన్టీఆర్ అన్న ని నటనకు 🙏🙏🙏🙏🙏🙏 ఎన్ని సార్లు చూసిన కళ్ళలో నుండి కన్నీరు ఆగటం లేదు',
#  'Song of the year 😘😘😘🔥🔥🔥🔥',
#  'మన స్వాతంత్ర్య సమరయోధులు మనకు స్వాతత్య్రం తేవడానికి ఎంత వీరోచితంగా పోరాడారో మనం చూడలేదు. కానీ అన్న నువ్వు ఆ పాత్రకు జీవం పోస్తే తెస్తుంది.అన్న మన వీరుల ప్రాణత్యాగాలు వాళ్ళు బ్రిటిష్ వాళ్ళతో పోరాడిన విధానం.అన్న NTR ని నటనకు సెల్యూట్ అన్న.జై కొమరం భీమ్ జై ntr.',
#  'Telugu legendary , director K. Viswanath garu anna gari perfomence chusi ascharypoyaru',
#  'Excellent song... I like it...',
#  'Jai ntr anna',
#  'Never before ever after performance by JR.NTR Anna.',
#  'నేను పవన్ కళ్యాణ్ గారి భక్తుడిని కానీ ఈ పాటలో NTR అన్న నీ నటన అద్భుతం అనే కన్న ఈ పాటలో జీవించావు మా రామ్ చరణ్ అన్న నువ్వు ఎప్పుడూ మీ స్నేహం ఇలాగే ఉండాలి ఉంటుంది అని మనస్ఫూర్తిగా కోరుకుంటున్నాను జై పవన్ కళ్యాణ్ గారు 🙏🙏🙏',
#  'Excellent performance',
#  'Super song 👏🌹🌹 Gayatri Prasad',
#  'ఎప్పటి నుంచో ఎదురుచూస్తున్న పాట వచ్చిందో.........జై ntr',
#  'వాహ్ ఏమి నటన సోదరా నీది తెలుగు భాష పై నీకున్న పట్టు ఇష్టం అమోఘం, నీ నటనకు దేశం మొత్తం ఫిదా అవుతుంది..',
#  'The song that touched millions of souls and hearts across the world\n#KomuramBheemudho',
#  'National award winner NTR 🔥🔥🔥',
#  'Tarak anna you brought moisture in my eyes when I was watching RRR in theatre! You are great bhai',
#  'Jai NTR ❤🔥',
#  'NTR ee scene lo matram \nOutstanding performance.',
#  '4:33 goosebumps',
#  "Marvelous acting from NTR sir, Being a hero is in your nature. You're nailed it. 👏",
#  'NTR is the dynamic and legendary actor love you sir  💓💓💓💓✊✊✊✊✊✊✊💪💪💪💪💪💪💪🐯🐯🐯🐯🐯',
#  'NTR just nailed it, he brought life to the music and song. No actor other than NTR sir would have done justice to this song',
#  'Ultimate emotion NTR\nUltimate expression RCT',
#  'Outstanding NTR 🔥🔥🔥',
#  'I like this song if i open u tube i will see first this song only ❤ jai ntr',
#  'Super sentiment song. Ntr expression super sentiment. I love this song.',
#  'సూపర్ సూపర్ సూపర్ సూపర్ సూపర్ సూపర్ సూపర్ సూపర్ సూపర్ సూపర్ సూపర్ సూపర్ సూపర్ సూపర్',
#  'This song gave me Goose bumps in the theatre 🔥🔥🔥 ఇదొక్క పాట చాలు తారక్ అన్న నటన ఎంత గొప్పదో చెప్పడానికి🙏🙏🙏🙏',
#  'NTR.. నటన లో తిరుగులేని రారాజు...తెలుగు సినిమా పరిశ్రమ గర్వంచదగ్గ నటుడు...NTR లోని నటనని వాడుకుంటే ఎవరైనా ఆయనకీ దాసోహం అయిపోతారు..like. RRR, Temper',
#  'ఈ అద్భుత మయిన దృశ్య కావ్యం రాజమౌళి గారికి రామజోగయ్య శాస్త్రి లిరిక్స్ కీరవాణి మ్యూజిక్ ఎన్టీఆర్ మరియు రామ్ చరణ్ యాక్టింగ్ హ్యాండ్స్ అప్ 🙏🏼🙏🏼🔥🔥',
#  'NTRrrrrrrrrrr......the expressions are ultimate',
#  'All time best performance of ntr',
#  'Jai NTR 💞💞💞',
#  'Proud to be a Ntr fan 🙏❤️',
#  'ఎంత అద్భుతమైన ప్రదర్శన? ఈ పాట చూసిన ప్రతిసారీ నా కళ్లలో నీళ్లు తిరుగుతున్నాయి... హ్యాట్సాఫ్ జూనియర్ ఎన్టీఆర్ సార్... a fan from tamilnadu',
#  'Thank you so much\nFor the video\nAwesome performance By NTR\nAll time favourite',
#  '🙏🙏✌️Jai NTR ✌️🙏🙏💪💪',
#  'Iddaru pekadesaru ... What an expressions by tarak anna and wat ehh reactions by charan anna . \nEven jr artists also nailed it .',
#  'Unbelievable song',
#  'Wow what a song it is! The way they picturised and the way the great actors potrayed the amotions in this song is next level. The BHEEM in the way to motivate and bring revelation in his people and RAMARAJU in his way to reduce the punishment of Bheem and bring him out of British clusters.💖💖💖RC',
#  'best song and best acting by both super stars for this decade']

# %%
len(comments)
# Out:
# 2638

# %%
#Creating dataframe
Youtube=pd.DataFrame({})
Youtube['Comments'] = comments[:500]
Youtube['Comment_time'] = comment_time[:500]
Youtube['Comment upvotes'] = No_of_Likes[:500]

#Printing dataframe
Youtube
# Out:
#                                               Comments          Comment_time  \
# 0    ఈ సినిమా ప్రపంచ వ్యాప్తంగా భారీ విజయం\nసాధించి...           2 weeks ago
# 1    థియేటర్ లో ఈ సీన్ చూస్తున్నంత సేపు కన్నీళ్లు ఆ...  2 weeks ago (edited)
# 2    నటనలో అద్భుతాలు సృష్టించగల ఒకేఒక నటుడు జూ.ఎన్ట...           2 weeks ago
# 3    అన్న ఎన్టీఆర్ నటనకు ఆస్కార్ అవార్డు ఇవ్వాలి అన...           2 weeks ago
# 4    రామ్ చరణ్ గారి నటన అద్భుతం. ఒక వైపు బాధ,మరో వై...           2 weeks ago
# ..                                                 ...                   ...
# 495                                 🙏🙏✌️Jai NTR ✌️🙏🙏💪💪           2 weeks ago
# 496  Iddaru pekadesaru ... What an expressions by t...            9 days ago
# 497                                  Unbelievable song           2 weeks ago
# 498  Wow what a song it is! The way they picturised...           2 weeks ago
# 499  best song and best acting by both super stars ...           2 weeks ago
#
#     Comment upvotes
# 0              2.9K
# 1              1.2K
# 2               672
# 3                93
# 4               290
# ..              ...
# 495
# 496
# 497               1
# 498              12
# 499
#
# [500 rows x 3 columns]

# %% [markdown]
# ### 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
# to get web browser
driver=webdriver.Chrome(r"C:\Users\youra\OneDrive\Desktop\SAI_dsp35\Datatrained\chromedriver.exe") 
time.sleep(3)

# to get url
url = "https://www.hostelworld.com/"
driver.get(url)

# %%
driver.maximize_window()

# %%
search_bar = driver.find_element_by_xpath("/html/body/div[3]/div/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[1]/div/div/div/input")    # Locating searc_bar by id
search_bar.clear()
search_bar.send_keys("london")

# %%
londonselect = driver.find_element_by_xpath("/html/body/div[3]/div/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]/div")
londonselect.click()

# %%
search_btn = driver.find_element_by_id('search-button')
search_btn.click()

# %%
hostelname=[]
distancecc=[]
ratings=[]
totalreviews=[]
overallreviews=[]
pvtfromprice=[]
dormsfromprice=[]
facilitiesNpropDescr=[]

time.sleep(3)
#Scrapping hostel name
hn=driver.find_elements_by_xpath("//h2[@class='title title-6']")
for i in hn:
    hostelname.append(i.text)

# %%
dcc=driver.find_elements_by_xpath("//span[@class='description']")
for i in dcc:
    distancecc.append(i.text)
    
totrs=driver.find_elements_by_xpath("//div[@class='reviews']")
for i in totrs:
    totalreviews.append(i.text)
    
ovrs=driver.find_elements_by_xpath("/html/body/div[3]/div/div/div[1]/div[4]/div/div/div[3]/div[2]/div[2]/a/div/div[2]/div[1]/span")
for i in ovrs:
    overallreviews.append(i.text)
    
fac=driver.find_elements_by_xpath("//div[@class='rating-factors prop-card-tablet rating-factors small']")
for i in fac:
    facilitiesNpropDescr.append(i.text)

# %%
try:                                                                  
    rating=driver.find_elements_by_xpath("//div[@class='score orange big']")
    ratings.append(rating.text)
        
except:
    r1=driver.find_elements_by_xpath("//div[@class='score grey big']")
    ratings.append("r1.text")

# %%
pvts=driver.find_elements_by_xpath("//div[@class='price-col']")
for i in pvts:
    pvtfromprice.append(i.text)

# %%
pvts1=[pvtfromprice[x] for x in range(0,len(pvtfromprice),2)]
dormsfromprice=[pvtfromprice[x] for x in range(1,len(pvtfromprice),2)]

# %%
ovrs=driver.find_elements_by_xpath("//div[@class='keyword']")
for i in ovrs:
    overallreviews.append(i.text)

# %%
london_hostels=pd.DataFrame({'hostel_name':hostelname,'distance_from_citycenter':distancecc,'Total_Reviews':totalreviews,
                 'DormsFromPrice':dormsfromprice,'PrivateFromPrice':pvts1,'Facilities_and_Properties_Description':facilitiesNpropDescr})
london_hostels.head()
# Out:
#                                hostel_name         distance_from_citycenter  \
# 0            Palmers Lodge - Swiss Cottage  Hostel - 6.5km from city centre
# 1                         Generator London    Hostel - 3km from city centre
# 2                     Urbany Hostel London  Hostel - 5.4km from city centre
# 3        Safestay London Elephant & Castle  Hostel - 1.7km from city centre
# 4  Safestay London Kensington Holland Park  Hostel - 5.9km from city centre
#
#          Total_Reviews      DormsFromPrice        PrivateFromPrice  \
# 0  15339 Total Reviews  Dorms From\nRs3398   No Privates Available
# 1   6939 Total Reviews  Dorms From\nRs2746   No Privates Available
# 2    306 Total Reviews  No Dorms Available  Privates From\nRs17092
# 3   4240 Total Reviews  Dorms From\nRs2837   No Privates Available
# 4   1191 Total Reviews  Dorms From\nRs2398   No Privates Available
#
#                Facilities_and_Properties_Description
# 0  Perfect Location\nSuperb Staff\nFantastic Clea...
# 1  Perfect Location\nMarvellous Staff\nAwesome Cl...
# 2  Perfect Location\nSuperb Staff\nFantastic Clea...
# 3  Wonderful Location\nMarvellous Staff\nAwesome ...
# 4               Wonderful Location\nMarvellous Staff

# %%
###################################################################################################################################

# %%
##############################################################################################################################

# %%
#####################################################################################################################################
